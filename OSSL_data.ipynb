# %%
import pandas as pd
from pymongo import MongoClient
data_dir = '../data/'

# %%
#CONFIG DATABASE Connection
user = 'soilspec4gg'
password = 'soilspec4gg'
host = 'api.soilspectroscopy.org'
db_name = 'soilspec4gg'
url = f"mongodb://{user}:{password}@{host}/{db_name}?ssl=true"

client = MongoClient(url, tlsAllowInvalidCertificates=True)
db = client[db_name]

# %%
#Some Helper functions
# Mongo is organized in db -> collections (tables) -> records
# A db has collections and each collection has tables


#List collections in db
def list_collections(db):
    return db.list_collection_names()

#query_format = {field: filter_value}
def get_data_collection(db,collection_name,query):
    collection = db[collection_name]

    if query is None:
        query = {}
    
    data = list(collection.find(query))
    return pd.DataFrame(data)

#Get fields in the a specific colletion
def get_collection_fields(db, collection_name):
    collection = db[collection_name]
    # Fetching one document from the collection
    document = collection.find_one()
    if document is not None:
        return document.keys()
    else:
        return []

#Get a sample record from a collection
def get_sample_record(db, collection_name):
    collection = db[collection_name]
    # Fetching one document from the collection
    random_record = collection.aggregate([{'$sample': {'size': 1}}])
    return list(random_record)[0] if random_record else None

# %% [markdown]
# # BASIC DATA EXPLORATION

# %%
#What collections in data
list_collections()
# Out:
# ['soillab', 'mir', 'visnir', 'soilsite']

# %% [markdown]
# Available collections:
#
# **soilsite:** site information, e.g., coordinates, pedons, layers, etc.
#
# **soillab_L0:** original soil laboratory data (wet chemistry), e.g., soil texture, carbon, etc.
#
# **soillab_L1:** harmonized soil laboratory data (wet chemistry), e.g., soil texture, carbon, etc.
#
# **mir:** MIR spectral data in the 600-4000 cm-1 range with metadata.
#
# **visnir:** VisNIR spectral data in the 350-2500 nm range with metadata.
#
# **ossl_L0:** Whole OSSL with all separate tables joined at level 0.
#
# **ossl_L1:** Whole OSSL with all separate tables joined at level 1.

# %%
#Open all the data to see main descriptions (Mir and visnir are to big to completely load in my computer)
soillab = get_data_collection(db,'soillab')
# mir = get_data_collection(db,'mir') ##TO BIG TO LOAD
# visnir = get_data_collection(db,'visnir') ##TO BIG TO LOAD
soilsite = get_data_collection(db,'soilsite')

# %%
soillab.describe()
#64K records
# Out:
#        id_layer_local_c  acid_tea_usda4b2_cmolkg  al_ox_usda_4g2_wpct  \
# count      64872.000000              2625.000000         25544.000000
# mean      107448.139891                12.164177             0.261622
# std        64279.867075                13.824144             0.494833
# min          123.000000               -10.504993             0.000000
# 25%        50359.750000                 3.187023             0.064060
# 50%        96143.500000                 7.799616             0.121231
# 75%       176060.250000                15.993956             0.241587
# max       200831.000000               118.798651             8.802493
#
#        c_tot_usda_4h2_wpct  clay_tot_usda_3a1_wpct  oc_usda_calc_wpct  \
# count         64663.000000            45930.000000       64546.000000
# mean              5.103172               22.781703           4.731338
# std              10.733414               16.199049          10.786497
# min               0.000000               -0.040697          -0.936400
# 25%               0.522988                9.660600           0.340000
# 50%               1.433277               20.854123           1.010000
# 75%               3.435167               32.359668           2.714600
# max              78.452136               96.144211          78.450000
#
#        fe_ox_usda_4g2_wpct  n_tot_usda_4h2_wpct  ph_h2o_usda_4c1_index  \
# count         25543.000000         64663.000000           48681.000000
# mean              0.417243             0.279717               6.425914
# std               0.614882             0.573322               1.317005
# min               0.000000             0.000000               1.970000
# 25%               0.092084             0.050791               5.390000
# 50%               0.239660             0.110000               6.280000
# 75%               0.541915             0.233277               7.630000
# max              20.966663            41.901014              10.700000
#
#        ph_cacl2_usda_4c1_index  ...  p_meh3_usda_4d6_mgkg  \
# count             48680.000000  ...           1511.000000
# mean                  5.921011  ...             27.728670
# std                   1.388367  ...             54.330361
# min                   2.140000  ...              0.000000
# 25%                   4.790000  ...              3.511399
# 50%                   5.720000  ...             11.447185
# 75%                   7.260000  ...             30.776656
# max                  10.680000  ...            821.094690
#
#        k_meh3_usda_4d6_mgkg  na_meh3_usda_4d6_mgkg  mg_meh3_usda_4d6_mgkg  \
# count           1511.000000            1511.000000            1511.000000
# mean             187.479071             270.316491             499.479520
# std              199.920511            2562.314643             539.110826
# min                0.000000               0.000000               0.000000
# 25%               78.070083              11.349780              89.443903
# 50%              140.691374              28.551094             330.016530
# 75%              235.297324              98.591277             752.794747
# max             3050.820000           94743.286930            5608.598342
#
#        fe_meh3_usda_4d6_mgkg  pb_meh3_usda_4d6_mgkg  zn_meh3_usda_4d6_mgkg  \
# count            1511.000000            1511.000000            1511.000000
# mean              133.435287               1.547620               2.260538
# std               157.129994               2.339409               8.796174
# min                 0.000000               0.000000               0.000000
# 25%                53.763637               0.174093               0.311335
# 50%                92.926623               0.866050               0.887852
# 75%               161.740083               2.480293               2.175833
# max              2708.083047              49.711732             314.719259
#
#        mo_meh3_usda_4d6_mgkg  si_meh3_usda_4d6_mgkg  sr_meh3_usda_4d6_mgkg
# count            1511.000000            1511.000000            1511.000000
# mean                0.147248             458.301792              34.589484
# std                 0.197557             272.724600              55.980811
# min                 0.000000               0.000000               0.000000
# 25%                 0.020105             265.532284               6.269882
# 50%                 0.090684             440.085186              16.245025
# 75%                 0.175240             615.688240              33.861683
# max                 1.667415            2517.545244             525.064519
#
# [8 rows x 54 columns]

# %%
soilsite.describe()
#115K records
# Out:
#        longitude_wgs84_dd  latitude_wgs84_dd  location_error_any_m  \
# count       115360.000000      115367.000000         108548.000000
# mean           -99.694761          41.490550          18447.971174
# std             19.749183           7.045919          17329.315168
# min           -167.994145         -77.502194             30.000000
# 25%           -112.700730          38.460556             30.000000
# 50%            -97.718955          42.253505          20708.270621
# 75%            -85.443165          46.109565          30541.864690
# max            162.064750          77.573917         122431.660164
#
#        id_project_ascii_c  layer_sequence_usda_uint16  \
# count       117218.000000               117218.000000
# mean          4407.714404                  107.773542
# std            974.315386                  129.365506
# min              4.000000                    1.000000
# 25%           4262.000000                   21.000000
# 50%           4662.000000                   53.000000
# 75%           4913.000000                  140.000000
# max           5374.000000                  657.000000
#
#        layer_upper_depth_usda_cm  layer_lower_depth_usda_cm  \
# count              116675.000000              113603.000000
# mean                   25.860383                  44.037022
# std                    43.742321                  53.504713
# min                     0.000000                   0.000000
# 25%                     0.000000                  10.000000
# 50%                     7.000000                  24.000000
# 75%                    36.000000                  63.000000
# max                  1737.000000                1783.000000
#
#        horizon_designation_discontinuity_usda_c
# count                               4775.000000
# mean                                   2.207958
# std                                    0.543171
# min                                    2.000000
# 25%                                    2.000000
# 50%                                    2.000000
# 75%                                    2.000000
# max                                    7.000000

# %%
# From Mir sample record is too big to load all
get_sample_record(db,'mir')
# Out:
# {'_id': ObjectId('645bb3def1aab744907e5258'),
#  'id_scan_uuid_c': '8e68af029450b1975558673cab936536',
#  'id_scan_local_c': '286833',
#  'id_layer_uuid_c': '10558c90af851cd4ca4ed34d950ec30e',
#  'id_layer_local_c': 195842,
#  'model_name_utf8_txt': 'Bruker Vertex 70 with HTS-XT accessory',
#  'model_code_any_c': 'Bruker_Vertex_70.HTS.XT',
#  'method_light_source_any_c': 'KBr',
#  'method_preparation_any_c': '',
#  'scan_file_any_c': '286833XS01.0; 286833XS02.0; 286833XS03.0; 286833XS04.0',
#  'scan_date_begin_iso_8601_yyyy_mm_dd': '2019-10-18',
#  'scan_date_end_iso_8601_yyyy_mm_dd': '2019-10-18',
#  'scan_license_title_ascii_txt': 'CC-BY',
#  'scan_license_address_idn_url': 'https://ncsslabdatamart.sc.egov.usda.gov/datause.aspx',
#  'scan_doi_idf_c': '',
#  'scan_contact_name_utf8_txt': 'Scarlett Murphy',
#  'scan_contact_email_ietf_email': 'Scarlett.Murphy@usda.gov',
#  'scan_mir_nafreq_ossl_pct': 0.0,
#  'scan_mir_negfreq_ossl_pct': 0.0,
#  'scan_mir_extfreq_ossl_pct': 0.0,
#  'scan_mir_600_abs': 1575.0,
#  'scan_mir_602_abs': 1580.0,
#  'scan_mir_604_abs': 1587.0,
#  'scan_mir_606_abs': 1596.0,
#  'scan_mir_608_abs': 1605.0,
#  'scan_mir_610_abs': 1612.0,
#  'scan_mir_612_abs': 1617.0,
#  'scan_mir_614_abs': 1622.0,
#  'scan_mir_616_abs': 1627.0,
#  'scan_mir_618_abs': 1632.0,
#  'scan_mir_620_abs': 1636.0,
#  'scan_mir_622_abs': 1638.0,
#  'scan_mir_624_abs': 1639.0,
#  'scan_mir_626_abs': 1640.0,
#  'scan_mir_628_abs': 1640.0,
#  'scan_mir_630_abs': 1639.0,
#  'scan_mir_632_abs': 1636.0,
#  'scan_mir_634_abs': 1633.0,
#  'scan_mir_636_abs': 1631.0,
#  'scan_mir_638_abs': 1629.0,
#  'scan_mir_640_abs': 1627.0,
#  'scan_mir_642_abs': 1625.0,
#  'scan_mir_644_abs': 1624.0,
#  'scan_mir_646_abs': 1621.0,
#  'scan_mir_648_abs': 1617.0,
#  'scan_mir_650_abs': 1615.0,
#  'scan_mir_652_abs': 1612.0,
#  'scan_mir_654_abs': 1610.0,
#  'scan_mir_656_abs': 1609.0,
#  'scan_mir_658_abs': 1607.0,
#  'scan_mir_660_abs': 1605.0,
#  'scan_mir_662_abs': 1601.0,
#  'scan_mir_664_abs': 1594.0,
#  'scan_mir_666_abs': 1586.0,
#  'scan_mir_668_abs': 1581.0,
#  'scan_mir_670_abs': 1581.0,
#  'scan_mir_672_abs': 1580.0,
#  'scan_mir_674_abs': 1577.0,
#  'scan_mir_676_abs': 1574.0,
#  'scan_mir_678_abs': 1572.0,
#  'scan_mir_680_abs': 1571.0,
#  'scan_mir_682_abs': 1571.0,
#  'scan_mir_684_abs': 1572.0,
#  'scan_mir_686_abs': 1575.0,
#  'scan_mir_688_abs': 1580.0,
#  'scan_mir_690_abs': 1588.0,
#  'scan_mir_692_abs': 1599.0,
#  'scan_mir_694_abs': 1616.0,
#  'scan_mir_696_abs': 1635.0,
#  'scan_mir_698_abs': 1648.0,
#  'scan_mir_700_abs': 1640.0,
#  'scan_mir_702_abs': 1616.0,
#  'scan_mir_704_abs': 1602.0,
#  'scan_mir_706_abs': 1593.0,
#  'scan_mir_708_abs': 1592.0,
#  'scan_mir_710_abs': 1597.0,
#  'scan_mir_712_abs': 1596.0,
#  'scan_mir_714_abs': 1582.0,
#  'scan_mir_716_abs': 1562.0,
#  'scan_mir_718_abs': 1546.0,
#  'scan_mir_720_abs': 1534.0,
#  'scan_mir_722_abs': 1526.0,
#  'scan_mir_724_abs': 1521.0,
#  'scan_mir_726_abs': 1518.0,
#  'scan_mir_728_abs': 1515.0,
#  'scan_mir_730_abs': 1513.0,
#  'scan_mir_732_abs': 1509.0,
#  'scan_mir_734_abs': 1503.0,
#  'scan_mir_736_abs': 1496.0,
#  'scan_mir_738_abs': 1490.0,
#  'scan_mir_740_abs': 1485.0,
#  'scan_mir_742_abs': 1480.0,
#  'scan_mir_744_abs': 1476.0,
#  'scan_mir_746_abs': 1472.0,
#  'scan_mir_748_abs': 1468.0,
#  'scan_mir_750_abs': 1465.0,
#  'scan_mir_752_abs': 1462.0,
#  'scan_mir_754_abs': 1459.0,
#  'scan_mir_756_abs': 1456.0,
#  'scan_mir_758_abs': 1455.0,
#  'scan_mir_760_abs': 1455.0,
#  'scan_mir_762_abs': 1454.0,
#  'scan_mir_764_abs': 1454.0,
#  'scan_mir_766_abs': 1453.0,
#  'scan_mir_768_abs': 1451.0,
#  'scan_mir_770_abs': 1448.0,
#  'scan_mir_772_abs': 1441.0,
#  'scan_mir_774_abs': 1433.0,
#  'scan_mir_776_abs': 1427.0,
#  'scan_mir_778_abs': 1427.0,
#  'scan_mir_780_abs': 1434.0,
#  'scan_mir_782_abs': 1446.0,
#  'scan_mir_784_abs': 1463.0,
#  'scan_mir_786_abs': 1481.0,
#  'scan_mir_788_abs': 1494.0,
#  'scan_mir_790_abs': 1499.0,
#  'scan_mir_792_abs': 1496.0,
#  'scan_mir_794_abs': 1487.0,
#  'scan_mir_796_abs': 1481.0,
#  'scan_mir_798_abs': 1481.0,
#  'scan_mir_800_abs': 1489.0,
#  'scan_mir_802_abs': 1504.0,
#  'scan_mir_804_abs': 1525.0,
#  'scan_mir_806_abs': 1551.0,
#  'scan_mir_808_abs': 1584.0,
#  'scan_mir_810_abs': 1593.0,
#  'scan_mir_812_abs': 1582.0,
#  'scan_mir_814_abs': 1564.0,
#  'scan_mir_816_abs': 1544.0,
#  'scan_mir_818_abs': 1524.0,
#  'scan_mir_820_abs': 1504.0,
#  'scan_mir_822_abs': 1485.0,
#  'scan_mir_824_abs': 1467.0,
#  'scan_mir_826_abs': 1450.0,
#  'scan_mir_828_abs': 1434.0,
#  'scan_mir_830_abs': 1419.0,
#  'scan_mir_832_abs': 1405.0,
#  'scan_mir_834_abs': 1391.0,
#  'scan_mir_836_abs': 1378.0,
#  'scan_mir_838_abs': 1365.0,
#  'scan_mir_840_abs': 1352.0,
#  'scan_mir_842_abs': 1341.0,
#  'scan_mir_844_abs': 1333.0,
#  'scan_mir_846_abs': 1329.0,
#  'scan_mir_848_abs': 1322.0,
#  'scan_mir_850_abs': 1312.0,
#  'scan_mir_852_abs': 1302.0,
#  'scan_mir_854_abs': 1294.0,
#  'scan_mir_856_abs': 1287.0,
#  'scan_mir_858_abs': 1283.0,
#  'scan_mir_860_abs': 1280.0,
#  'scan_mir_862_abs': 1280.0,
#  'scan_mir_864_abs': 1284.0,
#  'scan_mir_866_abs': 1296.0,
#  'scan_mir_868_abs': 1324.0,
#  'scan_mir_870_abs': 1362.0,
#  'scan_mir_872_abs': 1392.0,
#  'scan_mir_874_abs': 1396.0,
#  'scan_mir_876_abs': 1374.0,
#  'scan_mir_878_abs': 1342.0,
#  'scan_mir_880_abs': 1312.0,
#  'scan_mir_882_abs': 1286.0,
#  'scan_mir_884_abs': 1267.0,
#  'scan_mir_886_abs': 1255.0,
#  'scan_mir_888_abs': 1249.0,
#  'scan_mir_890_abs': 1249.0,
#  'scan_mir_892_abs': 1250.0,
#  'scan_mir_894_abs': 1253.0,
#  'scan_mir_896_abs': 1256.0,
#  'scan_mir_898_abs': 1261.0,
#  'scan_mir_900_abs': 1266.0,
#  'scan_mir_902_abs': 1273.0,
#  'scan_mir_904_abs': 1279.0,
#  'scan_mir_906_abs': 1284.0,
#  'scan_mir_908_abs': 1289.0,
#  'scan_mir_910_abs': 1294.0,
#  'scan_mir_912_abs': 1297.0,
#  'scan_mir_914_abs': 1299.0,
#  'scan_mir_916_abs': 1298.0,
#  'scan_mir_918_abs': 1295.0,
#  'scan_mir_920_abs': 1292.0,
#  'scan_mir_922_abs': 1290.0,
#  'scan_mir_924_abs': 1287.0,
#  'scan_mir_926_abs': 1284.0,
#  'scan_mir_928_abs': 1282.0,
#  'scan_mir_930_abs': 1279.0,
#  'scan_mir_932_abs': 1277.0,
#  'scan_mir_934_abs': 1275.0,
#  'scan_mir_936_abs': 1274.0,
#  'scan_mir_938_abs': 1271.0,
#  'scan_mir_940_abs': 1269.0,
#  'scan_mir_942_abs': 1266.0,
#  'scan_mir_944_abs': 1264.0,
#  'scan_mir_946_abs': 1262.0,
#  'scan_mir_948_abs': 1259.0,
#  'scan_mir_950_abs': 1257.0,
#  'scan_mir_952_abs': 1254.0,
#  'scan_mir_954_abs': 1253.0,
#  'scan_mir_956_abs': 1251.0,
#  'scan_mir_958_abs': 1250.0,
#  'scan_mir_960_abs': 1248.0,
#  'scan_mir_962_abs': 1247.0,
#  'scan_mir_964_abs': 1246.0,
#  'scan_mir_966_abs': 1246.0,
#  'scan_mir_968_abs': 1245.0,
#  'scan_mir_970_abs': 1244.0,
#  'scan_mir_972_abs': 1243.0,
#  'scan_mir_974_abs': 1242.0,
#  'scan_mir_976_abs': 1241.0,
#  'scan_mir_978_abs': 1239.0,
#  'scan_mir_980_abs': 1238.0,
#  'scan_mir_982_abs': 1236.0,
#  'scan_mir_984_abs': 1234.0,
#  'scan_mir_986_abs': 1232.0,
#  'scan_mir_988_abs': 1230.0,
#  'scan_mir_990_abs': 1228.0,
#  'scan_mir_992_abs': 1226.0,
#  'scan_mir_994_abs': 1223.0,
#  'scan_mir_996_abs': 1220.0,
#  'scan_mir_998_abs': 1217.0,
#  'scan_mir_1000_abs': 1214.0,
#  'scan_mir_1002_abs': 1211.0,
#  'scan_mir_1004_abs': 1209.0,
#  'scan_mir_1006_abs': 1206.0,
#  'scan_mir_1008_abs': 1204.0,
#  'scan_mir_1010_abs': 1203.0,
#  'scan_mir_1012_abs': 1201.0,
#  'scan_mir_1014_abs': 1199.0,
#  'scan_mir_1016_abs': 1196.0,
#  'scan_mir_1018_abs': 1194.0,
#  'scan_mir_1020_abs': 1191.0,
#  'scan_mir_1022_abs': 1187.0,
#  'scan_mir_1024_abs': 1180.0,
#  'scan_mir_1026_abs': 1172.0,
#  'scan_mir_1028_abs': 1167.0,
#  'scan_mir_1030_abs': 1161.0,
#  'scan_mir_1032_abs': 1156.0,
#  'scan_mir_1034_abs': 1150.0,
#  'scan_mir_1036_abs': 1145.0,
#  'scan_mir_1038_abs': 1140.0,
#  'scan_mir_1040_abs': 1135.0,
#  'scan_mir_1042_abs': 1131.0,
#  'scan_mir_1044_abs': 1125.0,
#  'scan_mir_1046_abs': 1120.0,
#  'scan_mir_1048_abs': 1114.0,
#  'scan_mir_1050_abs': 1109.0,
#  'scan_mir_1052_abs': 1104.0,
#  'scan_mir_1054_abs': 1098.0,
#  'scan_mir_1056_abs': 1092.0,
#  'scan_mir_1058_abs': 1085.0,
#  'scan_mir_1060_abs': 1076.0,
#  'scan_mir_1062_abs': 1066.0,
#  'scan_mir_1064_abs': 1056.0,
#  'scan_mir_1066_abs': 1045.0,
#  'scan_mir_1068_abs': 1036.0,
#  'scan_mir_1070_abs': 1028.0,
#  'scan_mir_1072_abs': 1022.0,
#  'scan_mir_1074_abs': 1018.0,
#  'scan_mir_1076_abs': 1016.0,
#  'scan_mir_1078_abs': 1016.0,
#  'scan_mir_1080_abs': 1018.0,
#  'scan_mir_1082_abs': 1019.0,
#  'scan_mir_1084_abs': 1021.0,
#  'scan_mir_1086_abs': 1023.0,
#  'scan_mir_1088_abs': 1025.0,
#  'scan_mir_1090_abs': 1028.0,
#  'scan_mir_1092_abs': 1030.0,
#  'scan_mir_1094_abs': 1033.0,
#  'scan_mir_1096_abs': 1036.0,
#  'scan_mir_1098_abs': 1039.0,
#  'scan_mir_1100_abs': 1042.0,
#  'scan_mir_1102_abs': 1045.0,
#  'scan_mir_1104_abs': 1047.0,
#  'scan_mir_1106_abs': 1050.0,
#  'scan_mir_1108_abs': 1052.0,
#  'scan_mir_1110_abs': 1054.0,
#  'scan_mir_1112_abs': 1055.0,
#  'scan_mir_1114_abs': 1056.0,
#  'scan_mir_1116_abs': 1055.0,
#  'scan_mir_1118_abs': 1054.0,
#  'scan_mir_1120_abs': 1053.0,
#  'scan_mir_1122_abs': 1051.0,
#  'scan_mir_1124_abs': 1050.0,
#  'scan_mir_1126_abs': 1049.0,
#  'scan_mir_1128_abs': 1049.0,
#  'scan_mir_1130_abs': 1049.0,
#  'scan_mir_1132_abs': 1049.0,
#  'scan_mir_1134_abs': 1050.0,
#  'scan_mir_1136_abs': 1051.0,
#  'scan_mir_1138_abs': 1053.0,
#  'scan_mir_1140_abs': 1054.0,
#  'scan_mir_1142_abs': 1056.0,
#  'scan_mir_1144_abs': 1058.0,
#  'scan_mir_1146_abs': 1062.0,
#  'scan_mir_1148_abs': 1066.0,
#  'scan_mir_1150_abs': 1073.0,
#  'scan_mir_1152_abs': 1084.0,
#  'scan_mir_1154_abs': 1098.0,
#  'scan_mir_1156_abs': 1111.0,
#  'scan_mir_1158_abs': 1116.0,
#  'scan_mir_1160_abs': 1109.0,
#  'scan_mir_1162_abs': 1094.0,
#  'scan_mir_1164_abs': 1079.0,
#  'scan_mir_1166_abs': 1067.0,
#  'scan_mir_1168_abs': 1060.0,
#  'scan_mir_1170_abs': 1055.0,
#  'scan_mir_1172_abs': 1052.0,
#  'scan_mir_1174_abs': 1050.0,
#  'scan_mir_1176_abs': 1048.0,
#  'scan_mir_1178_abs': 1047.0,
#  'scan_mir_1180_abs': 1046.0,
#  'scan_mir_1182_abs': 1045.0,
#  'scan_mir_1184_abs': 1043.0,
#  'scan_mir_1186_abs': 1041.0,
#  'scan_mir_1188_abs': 1039.0,
#  'scan_mir_1190_abs': 1037.0,
#  'scan_mir_1192_abs': 1035.0,
#  'scan_mir_1194_abs': 1033.0,
#  'scan_mir_1196_abs': 1030.0,
#  'scan_mir_1198_abs': 1027.0,
#  'scan_mir_1200_abs': 1023.0,
#  'scan_mir_1202_abs': 1020.0,
#  'scan_mir_1204_abs': 1016.0,
#  'scan_mir_1206_abs': 1013.0,
#  'scan_mir_1208_abs': 1010.0,
#  'scan_mir_1210_abs': 1007.0,
#  'scan_mir_1212_abs': 1004.0,
#  'scan_mir_1214_abs': 1003.0,
#  'scan_mir_1216_abs': 1002.0,
#  'scan_mir_1218_abs': 1002.0,
#  'scan_mir_1220_abs': 1004.0,
#  'scan_mir_1222_abs': 1008.0,
#  'scan_mir_1224_abs': 1014.0,
#  'scan_mir_1226_abs': 1022.0,
#  'scan_mir_1228_abs': 1032.0,
#  'scan_mir_1230_abs': 1042.0,
#  'scan_mir_1232_abs': 1053.0,
#  'scan_mir_1234_abs': 1063.0,
#  'scan_mir_1236_abs': 1073.0,
#  'scan_mir_1238_abs': 1081.0,
#  'scan_mir_1240_abs': 1091.0,
#  'scan_mir_1242_abs': 1099.0,
#  'scan_mir_1244_abs': 1103.0,
#  'scan_mir_1246_abs': 1106.0,
#  'scan_mir_1248_abs': 1108.0,
#  'scan_mir_1250_abs': 1110.0,
#  'scan_mir_1252_abs': 1112.0,
#  'scan_mir_1254_abs': 1115.0,
#  'scan_mir_1256_abs': 1118.0,
#  'scan_mir_1258_abs': 1121.0,
#  'scan_mir_1260_abs': 1125.0,
#  'scan_mir_1262_abs': 1129.0,
#  'scan_mir_1264_abs': 1132.0,
#  'scan_mir_1266_abs': 1134.0,
#  'scan_mir_1268_abs': 1136.0,
#  'scan_mir_1270_abs': 1137.0,
#  'scan_mir_1272_abs': 1138.0,
#  'scan_mir_1274_abs': 1138.0,
#  'scan_mir_1276_abs': 1139.0,
#  'scan_mir_1278_abs': 1138.0,
#  'scan_mir_1280_abs': 1137.0,
#  'scan_mir_1282_abs': 1135.0,
#  'scan_mir_1284_abs': 1132.0,
#  'scan_mir_1286_abs': 1129.0,
#  'scan_mir_1288_abs': 1125.0,
#  'scan_mir_1290_abs': 1122.0,
#  'scan_mir_1292_abs': 1119.0,
#  'scan_mir_1294_abs': 1116.0,
#  'scan_mir_1296_abs': 1113.0,
#  'scan_mir_1298_abs': 1112.0,
#  'scan_mir_1300_abs': 1110.0,
#  'scan_mir_1302_abs': 1109.0,
#  'scan_mir_1304_abs': 1108.0,
#  'scan_mir_1306_abs': 1108.0,
#  'scan_mir_1308_abs': 1108.0,
#  'scan_mir_1310_abs': 1108.0,
#  'scan_mir_1312_abs': 1108.0,
#  'scan_mir_1314_abs': 1107.0,
#  'scan_mir_1316_abs': 1105.0,
#  'scan_mir_1318_abs': 1103.0,
#  'scan_mir_1320_abs': 1101.0,
#  'scan_mir_1322_abs': 1098.0,
#  'scan_mir_1324_abs': 1095.0,
#  'scan_mir_1326_abs': 1093.0,
#  'scan_mir_1328_abs': 1091.0,
#  'scan_mir_1330_abs': 1089.0,
#  'scan_mir_1332_abs': 1088.0,
#  'scan_mir_1334_abs': 1087.0,
#  'scan_mir_1336_abs': 1086.0,
#  'scan_mir_1338_abs': 1085.0,
#  'scan_mir_1340_abs': 1084.0,
#  'scan_mir_1342_abs': 1084.0,
#  'scan_mir_1344_abs': 1083.0,
#  'scan_mir_1346_abs': 1083.0,
#  'scan_mir_1348_abs': 1082.0,
#  'scan_mir_1350_abs': 1082.0,
#  'scan_mir_1352_abs': 1083.0,
#  'scan_mir_1354_abs': 1086.0,
#  'scan_mir_1356_abs': 1089.0,
#  'scan_mir_1358_abs': 1093.0,
#  'scan_mir_1360_abs': 1099.0,
#  'scan_mir_1362_abs': 1106.0,
#  'scan_mir_1364_abs': 1115.0,
#  'scan_mir_1366_abs': 1125.0,
#  'scan_mir_1368_abs': 1136.0,
#  'scan_mir_1370_abs': 1147.0,
#  'scan_mir_1372_abs': 1158.0,
#  'scan_mir_1374_abs': 1171.0,
#  'scan_mir_1376_abs': 1183.0,
#  'scan_mir_1378_abs': 1195.0,
#  'scan_mir_1380_abs': 1208.0,
#  'scan_mir_1382_abs': 1224.0,
#  'scan_mir_1384_abs': 1240.0,
#  'scan_mir_1386_abs': 1257.0,
#  'scan_mir_1388_abs': 1276.0,
#  'scan_mir_1390_abs': 1294.0,
#  'scan_mir_1392_abs': 1312.0,
#  'scan_mir_1394_abs': 1330.0,
#  'scan_mir_1396_abs': 1349.0,
#  'scan_mir_1398_abs': 1364.0,
#  'scan_mir_1400_abs': 1375.0,
#  'scan_mir_1402_abs': 1382.0,
#  'scan_mir_1404_abs': 1386.0,
#  'scan_mir_1406_abs': 1394.0,
#  'scan_mir_1408_abs': 1405.0,
#  'scan_mir_1410_abs': 1419.0,
#  'scan_mir_1412_abs': 1434.0,
#  'scan_mir_1414_abs': 1446.0,
#  'scan_mir_1416_abs': 1458.0,
#  'scan_mir_1418_abs': 1470.0,
#  'scan_mir_1420_abs': 1481.0,
#  'scan_mir_1422_abs': 1491.0,
#  'scan_mir_1424_abs': 1501.0,
#  'scan_mir_1426_abs': 1510.0,
#  'scan_mir_1428_abs': 1519.0,
#  'scan_mir_1430_abs': 1528.0,
#  'scan_mir_1432_abs': 1535.0,
#  'scan_mir_1434_abs': 1541.0,
#  'scan_mir_1436_abs': 1547.0,
#  'scan_mir_1438_abs': 1553.0,
#  'scan_mir_1440_abs': 1558.0,
#  'scan_mir_1442_abs': 1562.0,
#  'scan_mir_1444_abs': 1564.0,
#  'scan_mir_1446_abs': 1567.0,
#  'scan_mir_1448_abs': 1568.0,
#  'scan_mir_1450_abs': 1570.0,
#  'scan_mir_1452_abs': 1570.0,
#  'scan_mir_1454_abs': 1570.0,
#  'scan_mir_1456_abs': 1569.0,
#  'scan_mir_1458_abs': 1571.0,
#  'scan_mir_1460_abs': 1570.0,
#  'scan_mir_1462_abs': 1569.0,
#  'scan_mir_1464_abs': 1568.0,
#  'scan_mir_1466_abs': 1567.0,
#  'scan_mir_1468_abs': 1565.0,
#  'scan_mir_1470_abs': 1562.0,
#  'scan_mir_1472_abs': 1560.0,
#  'scan_mir_1474_abs': 1559.0,
#  'scan_mir_1476_abs': 1558.0,
#  'scan_mir_1478_abs': 1557.0,
#  'scan_mir_1480_abs': 1555.0,
#  'scan_mir_1482_abs': 1553.0,
#  'scan_mir_1484_abs': 1551.0,
#  'scan_mir_1486_abs': 1548.0,
#  'scan_mir_1488_abs': 1545.0,
#  'scan_mir_1490_abs': 1543.0,
#  'scan_mir_1492_abs': 1541.0,
#  'scan_mir_1494_abs': 1537.0,
#  'scan_mir_1496_abs': 1534.0,
#  'scan_mir_1498_abs': 1530.0,
#  'scan_mir_1500_abs': 1528.0,
#  'scan_mir_1502_abs': 1524.0,
#  'scan_mir_1504_abs': 1520.0,
#  'scan_mir_1506_abs': 1514.0,
#  'scan_mir_1508_abs': 1511.0,
#  'scan_mir_1510_abs': 1507.0,
#  'scan_mir_1512_abs': 1500.0,
#  'scan_mir_1514_abs': 1494.0,
#  'scan_mir_1516_abs': 1487.0,
#  'scan_mir_1518_abs': 1479.0,
#  'scan_mir_1520_abs': 1468.0,
#  'scan_mir_1522_abs': 1456.0,
#  'scan_mir_1524_abs': 1442.0,
#  'scan_mir_1526_abs': 1425.0,
#  'scan_mir_1528_abs': 1407.0,
#  'scan_mir_1530_abs': 1387.0,
#  'scan_mir_1532_abs': 1364.0,
#  'scan_mir_1534_abs': 1342.0,
#  'scan_mir_1536_abs': 1323.0,
#  'scan_mir_1538_abs': 1301.0,
#  'scan_mir_1540_abs': 1277.0,
#  'scan_mir_1542_abs': 1259.0,
#  'scan_mir_1544_abs': 1242.0,
#  'scan_mir_1546_abs': 1227.0,
#  'scan_mir_1548_abs': 1214.0,
#  'scan_mir_1550_abs': 1202.0,
#  'scan_mir_1552_abs': 1194.0,
#  'scan_mir_1554_abs': 1190.0,
#  'scan_mir_1556_abs': 1188.0,
#  'scan_mir_1558_abs': 1189.0,
#  'scan_mir_1560_abs': 1195.0,
#  'scan_mir_1562_abs': 1202.0,
#  'scan_mir_1564_abs': 1210.0,
#  'scan_mir_1566_abs': 1219.0,
#  'scan_mir_1568_abs': 1227.0,
#  'scan_mir_1570_abs': 1235.0,
#  'scan_mir_1572_abs': 1244.0,
#  'scan_mir_1574_abs': 1255.0,
#  'scan_mir_1576_abs': 1270.0,
#  'scan_mir_1578_abs': 1283.0,
#  'scan_mir_1580_abs': 1294.0,
#  'scan_mir_1582_abs': 1306.0,
#  'scan_mir_1584_abs': 1317.0,
#  'scan_mir_1586_abs': 1328.0,
#  'scan_mir_1588_abs': 1338.0,
#  'scan_mir_1590_abs': 1348.0,
#  'scan_mir_1592_abs': 1356.0,
#  'scan_mir_1594_abs': 1365.0,
#  'scan_mir_1596_abs': 1374.0,
#  'scan_mir_1598_abs': 1383.0,
#  'scan_mir_1600_abs': 1392.0,
#  'scan_mir_1602_abs': 1402.0,
#  'scan_mir_1604_abs': 1411.0,
#  'scan_mir_1606_abs': 1421.0,
#  'scan_mir_1608_abs': 1431.0,
#  'scan_mir_1610_abs': 1442.0,
#  'scan_mir_1612_abs': 1451.0,
#  'scan_mir_1614_abs': 1460.0,
#  'scan_mir_1616_abs': 1469.0,
#  'scan_mir_1618_abs': 1483.0,
#  'scan_mir_1620_abs': 1495.0,
#  'scan_mir_1622_abs': 1501.0,
#  'scan_mir_1624_abs': 1507.0,
#  'scan_mir_1626_abs': 1512.0,
#  'scan_mir_1628_abs': 1516.0,
#  'scan_mir_1630_abs': 1519.0,
#  'scan_mir_1632_abs': 1519.0,
#  'scan_mir_1634_abs': 1519.0,
#  'scan_mir_1636_abs': 1519.0,
#  'scan_mir_1638_abs': 1518.0,
#  'scan_mir_1640_abs': 1515.0,
#  'scan_mir_1642_abs': 1510.0,
#  'scan_mir_1644_abs': 1504.0,
#  'scan_mir_1646_abs': 1497.0,
#  'scan_mir_1648_abs': 1491.0,
#  'scan_mir_1650_abs': 1484.0,
#  'scan_mir_1652_abs': 1474.0,
#  'scan_mir_1654_abs': 1466.0,
#  'scan_mir_1656_abs': 1460.0,
#  'scan_mir_1658_abs': 1452.0,
#  'scan_mir_1660_abs': 1442.0,
#  'scan_mir_1662_abs': 1431.0,
#  'scan_mir_1664_abs': 1420.0,
#  'scan_mir_1666_abs': 1410.0,
#  'scan_mir_1668_abs': 1399.0,
#  'scan_mir_1670_abs': 1387.0,
#  'scan_mir_1672_abs': 1371.0,
#  'scan_mir_1674_abs': 1354.0,
#  'scan_mir_1676_abs': 1344.0,
#  'scan_mir_1678_abs': 1332.0,
#  'scan_mir_1680_abs': 1320.0,
#  'scan_mir_1682_abs': 1304.0,
#  'scan_mir_1684_abs': 1288.0,
#  'scan_mir_1686_abs': 1274.0,
#  'scan_mir_1688_abs': 1259.0,
#  'scan_mir_1690_abs': 1243.0,
#  'scan_mir_1692_abs': 1226.0,
#  'scan_mir_1694_abs': 1207.0,
#  'scan_mir_1696_abs': 1189.0,
#  'scan_mir_1698_abs': 1171.0,
#  'scan_mir_1700_abs': 1154.0,
#  'scan_mir_1702_abs': 1139.0,
#  'scan_mir_1704_abs': 1126.0,
#  'scan_mir_1706_abs': 1112.0,
#  'scan_mir_1708_abs': 1099.0,
#  'scan_mir_1710_abs': 1087.0,
#  'scan_mir_1712_abs': 1075.0,
#  'scan_mir_1714_abs': 1063.0,
#  'scan_mir_1716_abs': 1051.0,
#  'scan_mir_1718_abs': 1040.0,
#  'scan_mir_1720_abs': 1032.0,
#  'scan_mir_1722_abs': 1024.0,
#  'scan_mir_1724_abs': 1016.0,
#  'scan_mir_1726_abs': 1005.0,
#  'scan_mir_1728_abs': 993.0,
#  'scan_mir_1730_abs': 986.0,
#  'scan_mir_1732_abs': 979.0,
#  'scan_mir_1734_abs': 973.0,
#  'scan_mir_1736_abs': 968.0,
#  'scan_mir_1738_abs': 963.0,
#  'scan_mir_1740_abs': 957.0,
#  'scan_mir_1742_abs': 952.0,
#  'scan_mir_1744_abs': 947.0,
#  'scan_mir_1746_abs': 942.0,
#  'scan_mir_1748_abs': 937.0,
#  'scan_mir_1750_abs': 933.0,
#  'scan_mir_1752_abs': 930.0,
#  'scan_mir_1754_abs': 928.0,
#  'scan_mir_1756_abs': 926.0,
#  'scan_mir_1758_abs': 925.0,
#  'scan_mir_1760_abs': 924.0,
#  'scan_mir_1762_abs': 925.0,
#  'scan_mir_1764_abs': 927.0,
#  'scan_mir_1766_abs': 929.0,
#  'scan_mir_1768_abs': 932.0,
#  'scan_mir_1770_abs': 936.0,
#  'scan_mir_1772_abs': 942.0,
#  'scan_mir_1774_abs': 948.0,
#  'scan_mir_1776_abs': 954.0,
#  'scan_mir_1778_abs': 960.0,
#  'scan_mir_1780_abs': 971.0,
#  'scan_mir_1782_abs': 986.0,
#  'scan_mir_1784_abs': 1001.0,
#  'scan_mir_1786_abs': 1022.0,
#  'scan_mir_1788_abs': 1048.0,
#  'scan_mir_1790_abs': 1076.0,
#  'scan_mir_1792_abs': 1097.0,
#  'scan_mir_1794_abs': 1104.0,
#  'scan_mir_1796_abs': 1099.0,
#  'scan_mir_1798_abs': 1082.0,
#  'scan_mir_1800_abs': 1053.0,
#  'scan_mir_1802_abs': 1018.0,
#  'scan_mir_1804_abs': 988.0,
#  'scan_mir_1806_abs': 965.0,
#  'scan_mir_1808_abs': 949.0,
#  'scan_mir_1810_abs': 936.0,
#  'scan_mir_1812_abs': 926.0,
#  'scan_mir_1814_abs': 917.0,
#  'scan_mir_1816_abs': 909.0,
#  'scan_mir_1818_abs': 902.0,
#  'scan_mir_1820_abs': 895.0,
#  'scan_mir_1822_abs': 887.0,
#  'scan_mir_1824_abs': 880.0,
#  'scan_mir_1826_abs': 872.0,
#  'scan_mir_1828_abs': 864.0,
#  'scan_mir_1830_abs': 857.0,
#  'scan_mir_1832_abs': 851.0,
#  'scan_mir_1834_abs': 844.0,
#  'scan_mir_1836_abs': 840.0,
#  'scan_mir_1838_abs': 840.0,
#  'scan_mir_1840_abs': 841.0,
#  'scan_mir_1842_abs': 843.0,
#  'scan_mir_1844_abs': 848.0,
#  'scan_mir_1846_abs': 855.0,
#  'scan_mir_1848_abs': 863.0,
#  'scan_mir_1850_abs': 872.0,
#  'scan_mir_1852_abs': 883.0,
#  'scan_mir_1854_abs': 894.0,
#  'scan_mir_1856_abs': 904.0,
#  'scan_mir_1858_abs': 914.0,
#  'scan_mir_1860_abs': 922.0,
#  'scan_mir_1862_abs': 929.0,
#  'scan_mir_1864_abs': 934.0,
#  'scan_mir_1866_abs': 936.0,
#  'scan_mir_1868_abs': 937.0,
#  'scan_mir_1870_abs': 937.0,
#  'scan_mir_1872_abs': 935.0,
#  'scan_mir_1874_abs': 932.0,
#  'scan_mir_1876_abs': 929.0,
#  'scan_mir_1878_abs': 925.0,
#  'scan_mir_1880_abs': 921.0,
#  'scan_mir_1882_abs': 916.0,
#  'scan_mir_1884_abs': 911.0,
#  'scan_mir_1886_abs': 906.0,
#  'scan_mir_1888_abs': 896.0,
#  'scan_mir_1890_abs': 885.0,
#  'scan_mir_1892_abs': 876.0,
#  'scan_mir_1894_abs': 867.0,
#  'scan_mir_1896_abs': 857.0,
#  'scan_mir_1898_abs': 847.0,
#  'scan_mir_1900_abs': 837.0,
#  'scan_mir_1902_abs': 825.0,
#  'scan_mir_1904_abs': 814.0,
#  'scan_mir_1906_abs': 802.0,
#  'scan_mir_1908_abs': 790.0,
#  'scan_mir_1910_abs': 778.0,
#  'scan_mir_1912_abs': 768.0,
#  'scan_mir_1914_abs': 758.0,
#  'scan_mir_1916_abs': 749.0,
#  'scan_mir_1918_abs': 742.0,
#  'scan_mir_1920_abs': 736.0,
#  'scan_mir_1922_abs': 732.0,
#  'scan_mir_1924_abs': 729.0,
#  'scan_mir_1926_abs': 727.0,
#  'scan_mir_1928_abs': 725.0,
#  'scan_mir_1930_abs': 724.0,
#  'scan_mir_1932_abs': 722.0,
#  'scan_mir_1934_abs': 721.0,
#  'scan_mir_1936_abs': 720.0,
#  'scan_mir_1938_abs': 719.0,
#  'scan_mir_1940_abs': 718.0,
#  'scan_mir_1942_abs': 717.0,
#  'scan_mir_1944_abs': 716.0,
#  'scan_mir_1946_abs': 715.0,
#  'scan_mir_1948_abs': 714.0,
#  'scan_mir_1950_abs': 712.0,
#  'scan_mir_1952_abs': 711.0,
#  'scan_mir_1954_abs': 710.0,
#  'scan_mir_1956_abs': 710.0,
#  'scan_mir_1958_abs': 710.0,
#  'scan_mir_1960_abs': 711.0,
#  'scan_mir_1962_abs': 712.0,
#  'scan_mir_1964_abs': 713.0,
#  'scan_mir_1966_abs': 714.0,
#  'scan_mir_1968_abs': 716.0,
#  'scan_mir_1970_abs': 717.0,
#  'scan_mir_1972_abs': 717.0,
#  'scan_mir_1974_abs': 717.0,
#  'scan_mir_1976_abs': 717.0,
#  'scan_mir_1978_abs': 716.0,
#  'scan_mir_1980_abs': 715.0,
#  'scan_mir_1982_abs': 714.0,
#  'scan_mir_1984_abs': 713.0,
#  'scan_mir_1986_abs': 712.0,
#  'scan_mir_1988_abs': 712.0,
#  'scan_mir_1990_abs': 711.0,
#  'scan_mir_1992_abs': 710.0,
#  'scan_mir_1994_abs': 709.0,
#  'scan_mir_1996_abs': 706.0,
#  'scan_mir_1998_abs': 703.0,
#  'scan_mir_2000_abs': 699.0,
#  'scan_mir_2002_abs': 695.0,
#  'scan_mir_2004_abs': 691.0,
#  'scan_mir_2006_abs': 685.0,
#  'scan_mir_2008_abs': 678.0,
#  'scan_mir_2010_abs': 670.0,
#  'scan_mir_2012_abs': 663.0,
#  'scan_mir_2014_abs': 655.0,
#  'scan_mir_2016_abs': 649.0,
#  'scan_mir_2018_abs': 643.0,
#  'scan_mir_2020_abs': 639.0,
#  'scan_mir_2022_abs': 635.0,
#  'scan_mir_2024_abs': 631.0,
#  'scan_mir_2026_abs': 627.0,
#  'scan_mir_2028_abs': 623.0,
#  'scan_mir_2030_abs': 618.0,
#  'scan_mir_2032_abs': 612.0,
#  'scan_mir_2034_abs': 605.0,
#  'scan_mir_2036_abs': 598.0,
#  'scan_mir_2038_abs': 590.0,
#  'scan_mir_2040_abs': 582.0,
#  'scan_mir_2042_abs': 574.0,
#  'scan_mir_2044_abs': 567.0,
#  'scan_mir_2046_abs': 561.0,
#  'scan_mir_2048_abs': 556.0,
#  'scan_mir_2050_abs': 549.0,
#  'scan_mir_2052_abs': 543.0,
#  'scan_mir_2054_abs': 540.0,
#  'scan_mir_2056_abs': 537.0,
#  'scan_mir_2058_abs': 534.0,
#  'scan_mir_2060_abs': 532.0,
#  'scan_mir_2062_abs': 529.0,
#  'scan_mir_2064_abs': 527.0,
#  'scan_mir_2066_abs': 526.0,
#  'scan_mir_2068_abs': 524.0,
#  'scan_mir_2070_abs': 522.0,
#  'scan_mir_2072_abs': 521.0,
#  'scan_mir_2074_abs': 519.0,
#  'scan_mir_2076_abs': 518.0,
#  'scan_mir_2078_abs': 517.0,
#  'scan_mir_2080_abs': 516.0,
#  'scan_mir_2082_abs': 514.0,
#  'scan_mir_2084_abs': 513.0,
#  'scan_mir_2086_abs': 512.0,
#  'scan_mir_2088_abs': 511.0,
#  'scan_mir_2090_abs': 510.0,
#  'scan_mir_2092_abs': 509.0,
#  'scan_mir_2094_abs': 508.0,
#  'scan_mir_2096_abs': 507.0,
#  'scan_mir_2098_abs': 506.0,
#  'scan_mir_2100_abs': 505.0,
#  'scan_mir_2102_abs': 504.0,
#  'scan_mir_2104_abs': 503.0,
#  'scan_mir_2106_abs': 502.0,
#  'scan_mir_2108_abs': 502.0,
#  'scan_mir_2110_abs': 501.0,
#  'scan_mir_2112_abs': 501.0,
#  'scan_mir_2114_abs': 501.0,
#  'scan_mir_2116_abs': 501.0,
#  'scan_mir_2118_abs': 501.0,
#  'scan_mir_2120_abs': 501.0,
#  'scan_mir_2122_abs': 502.0,
#  'scan_mir_2124_abs': 502.0,
#  'scan_mir_2126_abs': 503.0,
#  'scan_mir_2128_abs': 504.0,
#  'scan_mir_2130_abs': 505.0,
#  'scan_mir_2132_abs': 506.0,
#  'scan_mir_2134_abs': 506.0,
#  'scan_mir_2136_abs': 506.0,
#  'scan_mir_2138_abs': 505.0,
#  'scan_mir_2140_abs': 504.0,
#  'scan_mir_2142_abs': 503.0,
#  'scan_mir_2144_abs': 502.0,
#  'scan_mir_2146_abs': 500.0,
#  'scan_mir_2148_abs': 498.0,
#  'scan_mir_2150_abs': 497.0,
#  'scan_mir_2152_abs': 495.0,
#  'scan_mir_2154_abs': 493.0,
#  'scan_mir_2156_abs': 491.0,
#  'scan_mir_2158_abs': 488.0,
#  'scan_mir_2160_abs': 486.0,
#  'scan_mir_2162_abs': 484.0,
#  'scan_mir_2164_abs': 482.0,
#  'scan_mir_2166_abs': 481.0,
#  'scan_mir_2168_abs': 480.0,
#  'scan_mir_2170_abs': 478.0,
#  'scan_mir_2172_abs': 477.0,
#  'scan_mir_2174_abs': 476.0,
#  'scan_mir_2176_abs': 475.0,
#  'scan_mir_2178_abs': 474.0,
#  'scan_mir_2180_abs': 472.0,
#  'scan_mir_2182_abs': 471.0,
#  'scan_mir_2184_abs': 470.0,
#  'scan_mir_2186_abs': 469.0,
#  'scan_mir_2188_abs': 468.0,
#  'scan_mir_2190_abs': 468.0,
#  'scan_mir_2192_abs': 467.0,
#  'scan_mir_2194_abs': 466.0,
#  'scan_mir_2196_abs': 465.0,
#  'scan_mir_2198_abs': 465.0,
#  'scan_mir_2200_abs': 464.0,
#  'scan_mir_2202_abs': 464.0,
#  'scan_mir_2204_abs': 464.0,
#  'scan_mir_2206_abs': 463.0,
#  'scan_mir_2208_abs': 463.0,
#  'scan_mir_2210_abs': 463.0,
#  'scan_mir_2212_abs': 463.0,
#  'scan_mir_2214_abs': 463.0,
#  'scan_mir_2216_abs': 463.0,
#  'scan_mir_2218_abs': 464.0,
#  'scan_mir_2220_abs': 464.0,
#  'scan_mir_2222_abs': 463.0,
#  'scan_mir_2224_abs': 463.0,
#  'scan_mir_2226_abs': 463.0,
#  'scan_mir_2228_abs': 462.0,
#  'scan_mir_2230_abs': 462.0,
#  'scan_mir_2232_abs': 461.0,
#  'scan_mir_2234_abs': 460.0,
#  'scan_mir_2236_abs': 460.0,
#  'scan_mir_2238_abs': 459.0,
#  'scan_mir_2240_abs': 458.0,
#  'scan_mir_2242_abs': 456.0,
#  'scan_mir_2244_abs': 455.0,
#  'scan_mir_2246_abs': 454.0,
#  'scan_mir_2248_abs': 452.0,
#  'scan_mir_2250_abs': 451.0,
#  'scan_mir_2252_abs': 450.0,
#  'scan_mir_2254_abs': 448.0,
#  'scan_mir_2256_abs': 447.0,
#  'scan_mir_2258_abs': 446.0,
#  'scan_mir_2260_abs': 444.0,
#  'scan_mir_2262_abs': 443.0,
#  'scan_mir_2264_abs': 441.0,
#  'scan_mir_2266_abs': 439.0,
#  'scan_mir_2268_abs': 437.0,
#  'scan_mir_2270_abs': 436.0,
#  'scan_mir_2272_abs': 434.0,
#  'scan_mir_2274_abs': 433.0,
#  'scan_mir_2276_abs': 432.0,
#  'scan_mir_2278_abs': 430.0,
#  'scan_mir_2280_abs': 429.0,
#  'scan_mir_2282_abs': 427.0,
#  'scan_mir_2284_abs': 426.0,
#  'scan_mir_2286_abs': 424.0,
#  'scan_mir_2288_abs': 422.0,
#  'scan_mir_2290_abs': 421.0,
#  'scan_mir_2292_abs': 420.0,
#  'scan_mir_2294_abs': 418.0,
#  'scan_mir_2296_abs': 417.0,
#  'scan_mir_2298_abs': 416.0,
#  'scan_mir_2300_abs': 414.0,
#  'scan_mir_2302_abs': 413.0,
#  'scan_mir_2304_abs': 411.0,
#  'scan_mir_2306_abs': 410.0,
#  'scan_mir_2308_abs': 408.0,
#  'scan_mir_2310_abs': 406.0,
#  'scan_mir_2312_abs': 405.0,
#  'scan_mir_2314_abs': 403.0,
#  'scan_mir_2316_abs': 402.0,
#  'scan_mir_2318_abs': 398.0,
#  'scan_mir_2320_abs': 395.0,
#  'scan_mir_2322_abs': 393.0,
#  'scan_mir_2324_abs': 391.0,
#  'scan_mir_2326_abs': 389.0,
#  'scan_mir_2328_abs': 387.0,
#  'scan_mir_2330_abs': 386.0,
#  'scan_mir_2332_abs': 385.0,
#  'scan_mir_2334_abs': 384.0,
#  'scan_mir_2336_abs': 383.0,
#  'scan_mir_2338_abs': 382.0,
#  'scan_mir_2340_abs': 382.0,
#  'scan_mir_2342_abs': 382.0,
#  'scan_mir_2344_abs': 383.0,
#  'scan_mir_2346_abs': 385.0,
#  'scan_mir_2348_abs': 385.0,
#  'scan_mir_2350_abs': 381.0,
#  'scan_mir_2352_abs': 375.0,
#  'scan_mir_2354_abs': 369.0,
#  'scan_mir_2356_abs': 363.0,
#  'scan_mir_2358_abs': 360.0,
#  'scan_mir_2360_abs': 358.0,
#  'scan_mir_2362_abs': 358.0,
#  'scan_mir_2364_abs': 359.0,
#  'scan_mir_2366_abs': 361.0,
#  'scan_mir_2368_abs': 364.0,
#  'scan_mir_2370_abs': 367.0,
#  'scan_mir_2372_abs': 371.0,
#  'scan_mir_2374_abs': 374.0,
#  'scan_mir_2376_abs': 376.0,
#  'scan_mir_2378_abs': 377.0,
#  'scan_mir_2380_abs': 377.0,
#  'scan_mir_2382_abs': 377.0,
#  'scan_mir_2384_abs': 377.0,
#  'scan_mir_2386_abs': 376.0,
#  'scan_mir_2388_abs': 375.0,
#  'scan_mir_2390_abs': 375.0,
#  'scan_mir_2392_abs': 374.0,
#  'scan_mir_2394_abs': 373.0,
#  'scan_mir_2396_abs': 372.0,
#  'scan_mir_2398_abs': 372.0,
#  'scan_mir_2400_abs': 371.0,
#  'scan_mir_2402_abs': 370.0,
#  'scan_mir_2404_abs': 370.0,
#  'scan_mir_2406_abs': 369.0,
#  'scan_mir_2408_abs': 368.0,
#  'scan_mir_2410_abs': 368.0,
#  'scan_mir_2412_abs': 367.0,
#  'scan_mir_2414_abs': 367.0,
#  'scan_mir_2416_abs': 366.0,
#  'scan_mir_2418_abs': 366.0,
#  'scan_mir_2420_abs': 365.0,
#  'scan_mir_2422_abs': 365.0,
#  'scan_mir_2424_abs': 364.0,
#  'scan_mir_2426_abs': 364.0,
#  'scan_mir_2428_abs': 363.0,
#  'scan_mir_2430_abs': 363.0,
#  'scan_mir_2432_abs': 362.0,
#  'scan_mir_2434_abs': 362.0,
#  'scan_mir_2436_abs': 362.0,
#  'scan_mir_2438_abs': 362.0,
#  'scan_mir_2440_abs': 362.0,
#  'scan_mir_2442_abs': 362.0,
#  'scan_mir_2444_abs': 362.0,
#  'scan_mir_2446_abs': 362.0,
#  'scan_mir_2448_abs': 362.0,
#  'scan_mir_2450_abs': 362.0,
#  'scan_mir_2452_abs': 363.0,
#  'scan_mir_2454_abs': 363.0,
#  'scan_mir_2456_abs': 364.0,
#  'scan_mir_2458_abs': 365.0,
#  'scan_mir_2460_abs': 366.0,
#  'scan_mir_2462_abs': 367.0,
#  'scan_mir_2464_abs': 368.0,
#  'scan_mir_2466_abs': 370.0,
#  'scan_mir_2468_abs': 372.0,
#  'scan_mir_2470_abs': 375.0,
#  'scan_mir_2472_abs': 378.0,
#  'scan_mir_2474_abs': 382.0,
#  'scan_mir_2476_abs': 386.0,
#  'scan_mir_2478_abs': 391.0,
#  'scan_mir_2480_abs': 399.0,
#  'scan_mir_2482_abs': 408.0,
#  'scan_mir_2484_abs': 415.0,
#  'scan_mir_2486_abs': 423.0,
#  'scan_mir_2488_abs': 431.0,
#  'scan_mir_2490_abs': 441.0,
#  'scan_mir_2492_abs': 452.0,
#  'scan_mir_2494_abs': 464.0,
#  'scan_mir_2496_abs': 478.0,
#  'scan_mir_2498_abs': 492.0,
#  'scan_mir_2500_abs': 506.0,
#  'scan_mir_2502_abs': 520.0,
#  'scan_mir_2504_abs': 533.0,
#  'scan_mir_2506_abs': 545.0,
#  'scan_mir_2508_abs': 554.0,
#  'scan_mir_2510_abs': 560.0,
#  'scan_mir_2512_abs': 564.0,
#  'scan_mir_2514_abs': 566.0,
#  'scan_mir_2516_abs': 565.0,
#  'scan_mir_2518_abs': 564.0,
#  'scan_mir_2520_abs': 560.0,
#  'scan_mir_2522_abs': 554.0,
#  'scan_mir_2524_abs': 547.0,
#  'scan_mir_2526_abs': 538.0,
#  'scan_mir_2528_abs': 527.0,
#  'scan_mir_2530_abs': 516.0,
#  'scan_mir_2532_abs': 504.0,
#  'scan_mir_2534_abs': 487.0,
#  'scan_mir_2536_abs': 471.0,
#  'scan_mir_2538_abs': 464.0,
#  'scan_mir_2540_abs': 458.0,
#  'scan_mir_2542_abs': 455.0,
#  'scan_mir_2544_abs': 452.0,
#  'scan_mir_2546_abs': 449.0,
#  'scan_mir_2548_abs': 447.0,
#  'scan_mir_2550_abs': 444.0,
#  'scan_mir_2552_abs': 442.0,
#  'scan_mir_2554_abs': 439.0,
#  'scan_mir_2556_abs': 437.0,
#  'scan_mir_2558_abs': 434.0,
#  ...}

# %%
# From Mir sample record is too big to load all
get_sample_record(db,'visnir')
# Out:
# {'_id': ObjectId('645bb60af1aab744908206de'),
#  'id_scan_uuid_c': '29a3645ebc352c3640ea999d9ca69cd3',
#  'id_scan_local_c': 119377,
#  'id_layer_uuid_c': 'b71bde8a99f154ed2c35313785acdba1',
#  'id_layer_local_c': 46598,
#  'model_name_utf8_txt': 'ASD Labspec 2500 with Muglight accessory',
#  'model_code_any_c': 'ASD_Labspec_2500_MA',
#  'method_light_source_any_c': '',
#  'method_preparation_any_c': '',
#  'scan_file_any_c': '119377MD01.asd',
#  'scan_license_title_ascii_txt': 'CC-BY',
#  'scan_license_address_idn_url': 'https://ncsslabdatamart.sc.egov.usda.gov/datause.aspx',
#  'scan_doi_idf_c': '',
#  'scan_contact_name_utf8_txt': 'Scarlett Murphy',
#  'scan_contact_email_ietf_email': 'Scarlett.Murphy@usda.gov',
#  'scan_visnir_nafreq_ossl_pct': 0.0,
#  'scan_visnir_negfreq_ossl_pct': 0.0,
#  'scan_visnir_extfreq_ossl_pct': 0.0,
#  'scan_visnir_350_pcnt': 5.0,
#  'scan_visnir_352_pcnt': 5.0,
#  'scan_visnir_354_pcnt': 4.9,
#  'scan_visnir_356_pcnt': 4.5,
#  'scan_visnir_358_pcnt': 4.5,
#  'scan_visnir_360_pcnt': 4.4,
#  'scan_visnir_362_pcnt': 4.4,
#  'scan_visnir_364_pcnt': 4.4,
#  'scan_visnir_366_pcnt': 4.2,
#  'scan_visnir_368_pcnt': 4.2,
#  'scan_visnir_370_pcnt': 4.1,
#  'scan_visnir_372_pcnt': 4.1,
#  'scan_visnir_374_pcnt': 4.3,
#  'scan_visnir_376_pcnt': 4.1,
#  'scan_visnir_378_pcnt': 4.2,
#  'scan_visnir_380_pcnt': 4.2,
#  'scan_visnir_382_pcnt': 4.3,
#  'scan_visnir_384_pcnt': 4.3,
#  'scan_visnir_386_pcnt': 4.3,
#  'scan_visnir_388_pcnt': 4.3,
#  'scan_visnir_390_pcnt': 4.4,
#  'scan_visnir_392_pcnt': 4.3,
#  'scan_visnir_394_pcnt': 4.4,
#  'scan_visnir_396_pcnt': 4.5,
#  'scan_visnir_398_pcnt': 4.4,
#  'scan_visnir_400_pcnt': 4.5,
#  'scan_visnir_402_pcnt': 4.5,
#  'scan_visnir_404_pcnt': 4.5,
#  'scan_visnir_406_pcnt': 4.6,
#  'scan_visnir_408_pcnt': 4.6,
#  'scan_visnir_410_pcnt': 4.6,
#  'scan_visnir_412_pcnt': 4.7,
#  'scan_visnir_414_pcnt': 4.7,
#  'scan_visnir_416_pcnt': 4.7,
#  'scan_visnir_418_pcnt': 4.8,
#  'scan_visnir_420_pcnt': 4.8,
#  'scan_visnir_422_pcnt': 4.9,
#  'scan_visnir_424_pcnt': 5.0,
#  'scan_visnir_426_pcnt': 5.0,
#  'scan_visnir_428_pcnt': 5.1,
#  'scan_visnir_430_pcnt': 5.2,
#  'scan_visnir_432_pcnt': 5.3,
#  'scan_visnir_434_pcnt': 5.4,
#  'scan_visnir_436_pcnt': 5.5,
#  'scan_visnir_438_pcnt': 5.6,
#  'scan_visnir_440_pcnt': 5.6,
#  'scan_visnir_442_pcnt': 5.7,
#  'scan_visnir_444_pcnt': 5.8,
#  'scan_visnir_446_pcnt': 5.9,
#  'scan_visnir_448_pcnt': 6.0,
#  'scan_visnir_450_pcnt': 6.0,
#  'scan_visnir_452_pcnt': 6.1,
#  'scan_visnir_454_pcnt': 6.2,
#  'scan_visnir_456_pcnt': 6.2,
#  'scan_visnir_458_pcnt': 6.2,
#  'scan_visnir_460_pcnt': 6.3,
#  'scan_visnir_462_pcnt': 6.3,
#  'scan_visnir_464_pcnt': 6.3,
#  'scan_visnir_466_pcnt': 6.4,
#  'scan_visnir_468_pcnt': 6.4,
#  'scan_visnir_470_pcnt': 6.4,
#  'scan_visnir_472_pcnt': 6.5,
#  'scan_visnir_474_pcnt': 6.5,
#  'scan_visnir_476_pcnt': 6.6,
#  'scan_visnir_478_pcnt': 6.6,
#  'scan_visnir_480_pcnt': 6.7,
#  'scan_visnir_482_pcnt': 6.7,
#  'scan_visnir_484_pcnt': 6.8,
#  'scan_visnir_486_pcnt': 6.9,
#  'scan_visnir_488_pcnt': 7.0,
#  'scan_visnir_490_pcnt': 7.1,
#  'scan_visnir_492_pcnt': 7.2,
#  'scan_visnir_494_pcnt': 7.3,
#  'scan_visnir_496_pcnt': 7.4,
#  'scan_visnir_498_pcnt': 7.6,
#  'scan_visnir_500_pcnt': 7.7,
#  'scan_visnir_502_pcnt': 7.8,
#  'scan_visnir_504_pcnt': 7.9,
#  'scan_visnir_506_pcnt': 8.1,
#  'scan_visnir_508_pcnt': 8.2,
#  'scan_visnir_510_pcnt': 8.3,
#  'scan_visnir_512_pcnt': 8.5,
#  'scan_visnir_514_pcnt': 8.6,
#  'scan_visnir_516_pcnt': 8.7,
#  'scan_visnir_518_pcnt': 8.9,
#  'scan_visnir_520_pcnt': 9.0,
#  'scan_visnir_522_pcnt': 9.2,
#  'scan_visnir_524_pcnt': 9.4,
#  'scan_visnir_526_pcnt': 9.5,
#  'scan_visnir_528_pcnt': 9.7,
#  'scan_visnir_530_pcnt': 9.9,
#  'scan_visnir_532_pcnt': 10.1,
#  'scan_visnir_534_pcnt': 10.3,
#  'scan_visnir_536_pcnt': 10.6,
#  'scan_visnir_538_pcnt': 10.8,
#  'scan_visnir_540_pcnt': 11.1,
#  'scan_visnir_542_pcnt': 11.4,
#  'scan_visnir_544_pcnt': 11.7,
#  'scan_visnir_546_pcnt': 12.0,
#  'scan_visnir_548_pcnt': 12.3,
#  'scan_visnir_550_pcnt': 12.7,
#  'scan_visnir_552_pcnt': 13.1,
#  'scan_visnir_554_pcnt': 13.5,
#  'scan_visnir_556_pcnt': 13.9,
#  'scan_visnir_558_pcnt': 14.4,
#  'scan_visnir_560_pcnt': 14.9,
#  'scan_visnir_562_pcnt': 15.4,
#  'scan_visnir_564_pcnt': 16.0,
#  'scan_visnir_566_pcnt': 16.5,
#  'scan_visnir_568_pcnt': 17.0,
#  'scan_visnir_570_pcnt': 17.6,
#  'scan_visnir_572_pcnt': 18.1,
#  'scan_visnir_574_pcnt': 18.7,
#  'scan_visnir_576_pcnt': 19.2,
#  'scan_visnir_578_pcnt': 19.8,
#  'scan_visnir_580_pcnt': 20.3,
#  'scan_visnir_582_pcnt': 20.8,
#  'scan_visnir_584_pcnt': 21.4,
#  'scan_visnir_586_pcnt': 21.9,
#  'scan_visnir_588_pcnt': 22.3,
#  'scan_visnir_590_pcnt': 22.8,
#  'scan_visnir_592_pcnt': 23.2,
#  'scan_visnir_594_pcnt': 23.7,
#  'scan_visnir_596_pcnt': 24.1,
#  'scan_visnir_598_pcnt': 24.5,
#  'scan_visnir_600_pcnt': 24.9,
#  'scan_visnir_602_pcnt': 25.2,
#  'scan_visnir_604_pcnt': 25.5,
#  'scan_visnir_606_pcnt': 25.9,
#  'scan_visnir_608_pcnt': 26.2,
#  'scan_visnir_610_pcnt': 26.4,
#  'scan_visnir_612_pcnt': 26.7,
#  'scan_visnir_614_pcnt': 27.0,
#  'scan_visnir_616_pcnt': 27.2,
#  'scan_visnir_618_pcnt': 27.4,
#  'scan_visnir_620_pcnt': 27.6,
#  'scan_visnir_622_pcnt': 27.8,
#  'scan_visnir_624_pcnt': 28.0,
#  'scan_visnir_626_pcnt': 28.2,
#  'scan_visnir_628_pcnt': 28.4,
#  'scan_visnir_630_pcnt': 28.5,
#  'scan_visnir_632_pcnt': 28.7,
#  'scan_visnir_634_pcnt': 28.8,
#  'scan_visnir_636_pcnt': 29.0,
#  'scan_visnir_638_pcnt': 29.1,
#  'scan_visnir_640_pcnt': 29.3,
#  'scan_visnir_642_pcnt': 29.4,
#  'scan_visnir_644_pcnt': 29.6,
#  'scan_visnir_646_pcnt': 29.7,
#  'scan_visnir_648_pcnt': 29.8,
#  'scan_visnir_650_pcnt': 30.0,
#  'scan_visnir_652_pcnt': 30.1,
#  'scan_visnir_654_pcnt': 30.3,
#  'scan_visnir_656_pcnt': 30.4,
#  'scan_visnir_658_pcnt': 30.5,
#  'scan_visnir_660_pcnt': 30.7,
#  'scan_visnir_662_pcnt': 30.8,
#  'scan_visnir_664_pcnt': 31.0,
#  'scan_visnir_666_pcnt': 31.1,
#  'scan_visnir_668_pcnt': 31.3,
#  'scan_visnir_670_pcnt': 31.4,
#  'scan_visnir_672_pcnt': 31.6,
#  'scan_visnir_674_pcnt': 31.7,
#  'scan_visnir_676_pcnt': 31.9,
#  'scan_visnir_678_pcnt': 32.0,
#  'scan_visnir_680_pcnt': 32.2,
#  'scan_visnir_682_pcnt': 32.3,
#  'scan_visnir_684_pcnt': 32.5,
#  'scan_visnir_686_pcnt': 32.7,
#  'scan_visnir_688_pcnt': 32.8,
#  'scan_visnir_690_pcnt': 33.0,
#  'scan_visnir_692_pcnt': 33.2,
#  'scan_visnir_694_pcnt': 33.4,
#  'scan_visnir_696_pcnt': 33.5,
#  'scan_visnir_698_pcnt': 33.7,
#  'scan_visnir_700_pcnt': 33.9,
#  'scan_visnir_702_pcnt': 34.1,
#  'scan_visnir_704_pcnt': 34.3,
#  'scan_visnir_706_pcnt': 34.4,
#  'scan_visnir_708_pcnt': 34.6,
#  'scan_visnir_710_pcnt': 34.8,
#  'scan_visnir_712_pcnt': 35.0,
#  'scan_visnir_714_pcnt': 35.1,
#  'scan_visnir_716_pcnt': 35.3,
#  'scan_visnir_718_pcnt': 35.5,
#  'scan_visnir_720_pcnt': 35.6,
#  'scan_visnir_722_pcnt': 35.8,
#  'scan_visnir_724_pcnt': 36.0,
#  'scan_visnir_726_pcnt': 36.1,
#  'scan_visnir_728_pcnt': 36.3,
#  'scan_visnir_730_pcnt': 36.4,
#  'scan_visnir_732_pcnt': 36.5,
#  'scan_visnir_734_pcnt': 36.7,
#  'scan_visnir_736_pcnt': 36.8,
#  'scan_visnir_738_pcnt': 36.9,
#  'scan_visnir_740_pcnt': 37.0,
#  'scan_visnir_742_pcnt': 37.1,
#  'scan_visnir_744_pcnt': 37.2,
#  'scan_visnir_746_pcnt': 37.3,
#  'scan_visnir_748_pcnt': 37.4,
#  'scan_visnir_750_pcnt': 37.5,
#  'scan_visnir_752_pcnt': 37.6,
#  'scan_visnir_754_pcnt': 37.6,
#  'scan_visnir_756_pcnt': 37.7,
#  'scan_visnir_758_pcnt': 37.7,
#  'scan_visnir_760_pcnt': 37.8,
#  'scan_visnir_762_pcnt': 37.8,
#  'scan_visnir_764_pcnt': 37.8,
#  'scan_visnir_766_pcnt': 37.8,
#  'scan_visnir_768_pcnt': 37.9,
#  'scan_visnir_770_pcnt': 37.9,
#  'scan_visnir_772_pcnt': 37.9,
#  'scan_visnir_774_pcnt': 37.9,
#  'scan_visnir_776_pcnt': 37.8,
#  'scan_visnir_778_pcnt': 37.8,
#  'scan_visnir_780_pcnt': 37.8,
#  'scan_visnir_782_pcnt': 37.8,
#  'scan_visnir_784_pcnt': 37.7,
#  'scan_visnir_786_pcnt': 37.7,
#  'scan_visnir_788_pcnt': 37.7,
#  'scan_visnir_790_pcnt': 37.6,
#  'scan_visnir_792_pcnt': 37.6,
#  'scan_visnir_794_pcnt': 37.5,
#  'scan_visnir_796_pcnt': 37.4,
#  'scan_visnir_798_pcnt': 37.4,
#  'scan_visnir_800_pcnt': 37.3,
#  'scan_visnir_802_pcnt': 37.3,
#  'scan_visnir_804_pcnt': 37.2,
#  'scan_visnir_806_pcnt': 37.1,
#  'scan_visnir_808_pcnt': 37.1,
#  'scan_visnir_810_pcnt': 37.0,
#  'scan_visnir_812_pcnt': 36.9,
#  'scan_visnir_814_pcnt': 36.9,
#  'scan_visnir_816_pcnt': 36.8,
#  'scan_visnir_818_pcnt': 36.7,
#  'scan_visnir_820_pcnt': 36.7,
#  'scan_visnir_822_pcnt': 36.6,
#  'scan_visnir_824_pcnt': 36.5,
#  'scan_visnir_826_pcnt': 36.4,
#  'scan_visnir_828_pcnt': 36.4,
#  'scan_visnir_830_pcnt': 36.3,
#  'scan_visnir_832_pcnt': 36.2,
#  'scan_visnir_834_pcnt': 36.2,
#  'scan_visnir_836_pcnt': 36.1,
#  'scan_visnir_838_pcnt': 36.0,
#  'scan_visnir_840_pcnt': 36.0,
#  'scan_visnir_842_pcnt': 35.9,
#  'scan_visnir_844_pcnt': 35.9,
#  'scan_visnir_846_pcnt': 35.8,
#  'scan_visnir_848_pcnt': 35.8,
#  'scan_visnir_850_pcnt': 35.7,
#  'scan_visnir_852_pcnt': 35.7,
#  'scan_visnir_854_pcnt': 35.6,
#  'scan_visnir_856_pcnt': 35.6,
#  'scan_visnir_858_pcnt': 35.5,
#  'scan_visnir_860_pcnt': 35.5,
#  'scan_visnir_862_pcnt': 35.5,
#  'scan_visnir_864_pcnt': 35.4,
#  'scan_visnir_866_pcnt': 35.4,
#  'scan_visnir_868_pcnt': 35.4,
#  'scan_visnir_870_pcnt': 35.4,
#  'scan_visnir_872_pcnt': 35.3,
#  'scan_visnir_874_pcnt': 35.3,
#  'scan_visnir_876_pcnt': 35.3,
#  'scan_visnir_878_pcnt': 35.3,
#  'scan_visnir_880_pcnt': 35.3,
#  'scan_visnir_882_pcnt': 35.3,
#  'scan_visnir_884_pcnt': 35.3,
#  'scan_visnir_886_pcnt': 35.3,
#  'scan_visnir_888_pcnt': 35.3,
#  'scan_visnir_890_pcnt': 35.3,
#  'scan_visnir_892_pcnt': 35.3,
#  'scan_visnir_894_pcnt': 35.3,
#  'scan_visnir_896_pcnt': 35.3,
#  'scan_visnir_898_pcnt': 35.4,
#  'scan_visnir_900_pcnt': 35.4,
#  'scan_visnir_902_pcnt': 35.4,
#  'scan_visnir_904_pcnt': 35.5,
#  'scan_visnir_906_pcnt': 35.5,
#  'scan_visnir_908_pcnt': 35.5,
#  'scan_visnir_910_pcnt': 35.6,
#  'scan_visnir_912_pcnt': 35.6,
#  'scan_visnir_914_pcnt': 35.6,
#  'scan_visnir_916_pcnt': 35.7,
#  'scan_visnir_918_pcnt': 35.7,
#  'scan_visnir_920_pcnt': 35.8,
#  'scan_visnir_922_pcnt': 35.8,
#  'scan_visnir_924_pcnt': 35.9,
#  'scan_visnir_926_pcnt': 36.0,
#  'scan_visnir_928_pcnt': 36.0,
#  'scan_visnir_930_pcnt': 36.1,
#  'scan_visnir_932_pcnt': 36.1,
#  'scan_visnir_934_pcnt': 36.2,
#  'scan_visnir_936_pcnt': 36.3,
#  'scan_visnir_938_pcnt': 36.3,
#  'scan_visnir_940_pcnt': 36.4,
#  'scan_visnir_942_pcnt': 36.5,
#  'scan_visnir_944_pcnt': 36.6,
#  'scan_visnir_946_pcnt': 36.6,
#  'scan_visnir_948_pcnt': 36.7,
#  'scan_visnir_950_pcnt': 36.8,
#  'scan_visnir_952_pcnt': 36.9,
#  'scan_visnir_954_pcnt': 36.9,
#  'scan_visnir_956_pcnt': 37.0,
#  'scan_visnir_958_pcnt': 37.1,
#  'scan_visnir_960_pcnt': 37.2,
#  'scan_visnir_962_pcnt': 37.3,
#  'scan_visnir_964_pcnt': 37.3,
#  'scan_visnir_966_pcnt': 37.4,
#  'scan_visnir_968_pcnt': 37.5,
#  'scan_visnir_970_pcnt': 37.6,
#  'scan_visnir_972_pcnt': 37.8,
#  'scan_visnir_974_pcnt': 37.9,
#  'scan_visnir_976_pcnt': 38.0,
#  'scan_visnir_978_pcnt': 38.1,
#  'scan_visnir_980_pcnt': 38.2,
#  'scan_visnir_982_pcnt': 38.3,
#  'scan_visnir_984_pcnt': 38.4,
#  'scan_visnir_986_pcnt': 38.5,
#  'scan_visnir_988_pcnt': 38.6,
#  'scan_visnir_990_pcnt': 38.7,
#  'scan_visnir_992_pcnt': 38.8,
#  'scan_visnir_994_pcnt': 38.9,
#  'scan_visnir_996_pcnt': 39.0,
#  'scan_visnir_998_pcnt': 39.1,
#  'scan_visnir_1000_pcnt': 39.2,
#  'scan_visnir_1002_pcnt': 39.3,
#  'scan_visnir_1004_pcnt': 39.4,
#  'scan_visnir_1006_pcnt': 39.5,
#  'scan_visnir_1008_pcnt': 39.6,
#  'scan_visnir_1010_pcnt': 39.7,
#  'scan_visnir_1012_pcnt': 39.8,
#  'scan_visnir_1014_pcnt': 39.9,
#  'scan_visnir_1016_pcnt': 40.0,
#  'scan_visnir_1018_pcnt': 40.1,
#  'scan_visnir_1020_pcnt': 40.2,
#  'scan_visnir_1022_pcnt': 40.3,
#  'scan_visnir_1024_pcnt': 40.4,
#  'scan_visnir_1026_pcnt': 40.5,
#  'scan_visnir_1028_pcnt': 40.6,
#  'scan_visnir_1030_pcnt': 40.7,
#  'scan_visnir_1032_pcnt': 40.8,
#  'scan_visnir_1034_pcnt': 40.9,
#  'scan_visnir_1036_pcnt': 41.0,
#  'scan_visnir_1038_pcnt': 41.2,
#  'scan_visnir_1040_pcnt': 41.3,
#  'scan_visnir_1042_pcnt': 41.4,
#  'scan_visnir_1044_pcnt': 41.5,
#  'scan_visnir_1046_pcnt': 41.6,
#  'scan_visnir_1048_pcnt': 41.7,
#  'scan_visnir_1050_pcnt': 41.8,
#  'scan_visnir_1052_pcnt': 41.9,
#  'scan_visnir_1054_pcnt': 42.0,
#  'scan_visnir_1056_pcnt': 42.1,
#  'scan_visnir_1058_pcnt': 42.3,
#  'scan_visnir_1060_pcnt': 42.4,
#  'scan_visnir_1062_pcnt': 42.5,
#  'scan_visnir_1064_pcnt': 42.6,
#  'scan_visnir_1066_pcnt': 42.7,
#  'scan_visnir_1068_pcnt': 42.9,
#  'scan_visnir_1070_pcnt': 43.0,
#  'scan_visnir_1072_pcnt': 43.1,
#  'scan_visnir_1074_pcnt': 43.2,
#  'scan_visnir_1076_pcnt': 43.3,
#  'scan_visnir_1078_pcnt': 43.5,
#  'scan_visnir_1080_pcnt': 43.6,
#  'scan_visnir_1082_pcnt': 43.7,
#  'scan_visnir_1084_pcnt': 43.8,
#  'scan_visnir_1086_pcnt': 44.0,
#  'scan_visnir_1088_pcnt': 44.1,
#  'scan_visnir_1090_pcnt': 44.2,
#  'scan_visnir_1092_pcnt': 44.4,
#  'scan_visnir_1094_pcnt': 44.5,
#  'scan_visnir_1096_pcnt': 44.6,
#  'scan_visnir_1098_pcnt': 44.7,
#  'scan_visnir_1100_pcnt': 44.9,
#  'scan_visnir_1102_pcnt': 45.0,
#  'scan_visnir_1104_pcnt': 45.1,
#  'scan_visnir_1106_pcnt': 45.3,
#  'scan_visnir_1108_pcnt': 45.4,
#  'scan_visnir_1110_pcnt': 45.5,
#  'scan_visnir_1112_pcnt': 45.7,
#  'scan_visnir_1114_pcnt': 45.8,
#  'scan_visnir_1116_pcnt': 45.9,
#  'scan_visnir_1118_pcnt': 46.0,
#  'scan_visnir_1120_pcnt': 46.2,
#  'scan_visnir_1122_pcnt': 46.3,
#  'scan_visnir_1124_pcnt': 46.4,
#  'scan_visnir_1126_pcnt': 46.6,
#  'scan_visnir_1128_pcnt': 46.7,
#  'scan_visnir_1130_pcnt': 46.8,
#  'scan_visnir_1132_pcnt': 46.9,
#  'scan_visnir_1134_pcnt': 47.1,
#  'scan_visnir_1136_pcnt': 47.2,
#  'scan_visnir_1138_pcnt': 47.3,
#  'scan_visnir_1140_pcnt': 47.4,
#  'scan_visnir_1142_pcnt': 47.5,
#  'scan_visnir_1144_pcnt': 47.7,
#  'scan_visnir_1146_pcnt': 47.8,
#  'scan_visnir_1148_pcnt': 47.9,
#  'scan_visnir_1150_pcnt': 48.0,
#  'scan_visnir_1152_pcnt': 48.1,
#  'scan_visnir_1154_pcnt': 48.2,
#  'scan_visnir_1156_pcnt': 48.3,
#  'scan_visnir_1158_pcnt': 48.5,
#  'scan_visnir_1160_pcnt': 48.6,
#  'scan_visnir_1162_pcnt': 48.7,
#  'scan_visnir_1164_pcnt': 48.8,
#  'scan_visnir_1166_pcnt': 49.0,
#  'scan_visnir_1168_pcnt': 49.1,
#  'scan_visnir_1170_pcnt': 49.2,
#  'scan_visnir_1172_pcnt': 49.3,
#  'scan_visnir_1174_pcnt': 49.5,
#  'scan_visnir_1176_pcnt': 49.6,
#  'scan_visnir_1178_pcnt': 49.7,
#  'scan_visnir_1180_pcnt': 49.8,
#  'scan_visnir_1182_pcnt': 49.9,
#  'scan_visnir_1184_pcnt': 50.1,
#  'scan_visnir_1186_pcnt': 50.2,
#  'scan_visnir_1188_pcnt': 50.3,
#  'scan_visnir_1190_pcnt': 50.4,
#  'scan_visnir_1192_pcnt': 50.5,
#  'scan_visnir_1194_pcnt': 50.6,
#  'scan_visnir_1196_pcnt': 50.7,
#  'scan_visnir_1198_pcnt': 50.8,
#  'scan_visnir_1200_pcnt': 50.9,
#  'scan_visnir_1202_pcnt': 51.0,
#  'scan_visnir_1204_pcnt': 51.1,
#  'scan_visnir_1206_pcnt': 51.2,
#  'scan_visnir_1208_pcnt': 51.3,
#  'scan_visnir_1210_pcnt': 51.4,
#  'scan_visnir_1212_pcnt': 51.5,
#  'scan_visnir_1214_pcnt': 51.5,
#  'scan_visnir_1216_pcnt': 51.6,
#  'scan_visnir_1218_pcnt': 51.7,
#  'scan_visnir_1220_pcnt': 51.8,
#  'scan_visnir_1222_pcnt': 51.9,
#  'scan_visnir_1224_pcnt': 51.9,
#  'scan_visnir_1226_pcnt': 52.0,
#  'scan_visnir_1228_pcnt': 52.1,
#  'scan_visnir_1230_pcnt': 52.1,
#  'scan_visnir_1232_pcnt': 52.2,
#  'scan_visnir_1234_pcnt': 52.3,
#  'scan_visnir_1236_pcnt': 52.3,
#  'scan_visnir_1238_pcnt': 52.4,
#  'scan_visnir_1240_pcnt': 52.5,
#  'scan_visnir_1242_pcnt': 52.5,
#  'scan_visnir_1244_pcnt': 52.6,
#  'scan_visnir_1246_pcnt': 52.7,
#  'scan_visnir_1248_pcnt': 52.7,
#  'scan_visnir_1250_pcnt': 52.8,
#  'scan_visnir_1252_pcnt': 52.9,
#  'scan_visnir_1254_pcnt': 52.9,
#  'scan_visnir_1256_pcnt': 53.0,
#  'scan_visnir_1258_pcnt': 53.0,
#  'scan_visnir_1260_pcnt': 53.1,
#  'scan_visnir_1262_pcnt': 53.2,
#  'scan_visnir_1264_pcnt': 53.2,
#  'scan_visnir_1266_pcnt': 53.3,
#  'scan_visnir_1268_pcnt': 53.3,
#  'scan_visnir_1270_pcnt': 53.4,
#  'scan_visnir_1272_pcnt': 53.4,
#  'scan_visnir_1274_pcnt': 53.5,
#  'scan_visnir_1276_pcnt': 53.5,
#  'scan_visnir_1278_pcnt': 53.5,
#  'scan_visnir_1280_pcnt': 53.6,
#  'scan_visnir_1282_pcnt': 53.6,
#  'scan_visnir_1284_pcnt': 53.6,
#  'scan_visnir_1286_pcnt': 53.6,
#  'scan_visnir_1288_pcnt': 53.6,
#  'scan_visnir_1290_pcnt': 53.6,
#  'scan_visnir_1292_pcnt': 53.6,
#  'scan_visnir_1294_pcnt': 53.6,
#  'scan_visnir_1296_pcnt': 53.6,
#  'scan_visnir_1298_pcnt': 53.6,
#  'scan_visnir_1300_pcnt': 53.6,
#  'scan_visnir_1302_pcnt': 53.6,
#  'scan_visnir_1304_pcnt': 53.6,
#  'scan_visnir_1306_pcnt': 53.6,
#  'scan_visnir_1308_pcnt': 53.7,
#  'scan_visnir_1310_pcnt': 53.7,
#  'scan_visnir_1312_pcnt': 53.7,
#  'scan_visnir_1314_pcnt': 53.7,
#  'scan_visnir_1316_pcnt': 53.7,
#  'scan_visnir_1318_pcnt': 53.7,
#  'scan_visnir_1320_pcnt': 53.7,
#  'scan_visnir_1322_pcnt': 53.7,
#  'scan_visnir_1324_pcnt': 53.7,
#  'scan_visnir_1326_pcnt': 53.7,
#  'scan_visnir_1328_pcnt': 53.7,
#  'scan_visnir_1330_pcnt': 53.7,
#  'scan_visnir_1332_pcnt': 53.6,
#  'scan_visnir_1334_pcnt': 53.6,
#  'scan_visnir_1336_pcnt': 53.6,
#  'scan_visnir_1338_pcnt': 53.6,
#  'scan_visnir_1340_pcnt': 53.6,
#  'scan_visnir_1342_pcnt': 53.5,
#  'scan_visnir_1344_pcnt': 53.5,
#  'scan_visnir_1346_pcnt': 53.4,
#  'scan_visnir_1348_pcnt': 53.3,
#  'scan_visnir_1350_pcnt': 53.3,
#  'scan_visnir_1352_pcnt': 53.2,
#  'scan_visnir_1354_pcnt': 53.1,
#  'scan_visnir_1356_pcnt': 53.0,
#  'scan_visnir_1358_pcnt': 52.8,
#  'scan_visnir_1360_pcnt': 52.7,
#  'scan_visnir_1362_pcnt': 52.6,
#  'scan_visnir_1364_pcnt': 52.4,
#  'scan_visnir_1366_pcnt': 52.2,
#  'scan_visnir_1368_pcnt': 51.9,
#  'scan_visnir_1370_pcnt': 51.6,
#  'scan_visnir_1372_pcnt': 51.1,
#  'scan_visnir_1374_pcnt': 50.6,
#  'scan_visnir_1376_pcnt': 50.0,
#  'scan_visnir_1378_pcnt': 49.4,
#  'scan_visnir_1380_pcnt': 48.8,
#  'scan_visnir_1382_pcnt': 48.1,
#  'scan_visnir_1384_pcnt': 47.6,
#  'scan_visnir_1386_pcnt': 47.1,
#  'scan_visnir_1388_pcnt': 46.7,
#  'scan_visnir_1390_pcnt': 46.3,
#  'scan_visnir_1392_pcnt': 45.9,
#  'scan_visnir_1394_pcnt': 45.6,
#  'scan_visnir_1396_pcnt': 45.2,
#  'scan_visnir_1398_pcnt': 44.7,
#  'scan_visnir_1400_pcnt': 44.3,
#  'scan_visnir_1402_pcnt': 43.8,
#  'scan_visnir_1404_pcnt': 43.2,
#  'scan_visnir_1406_pcnt': 42.6,
#  'scan_visnir_1408_pcnt': 42.1,
#  'scan_visnir_1410_pcnt': 41.8,
#  'scan_visnir_1412_pcnt': 41.7,
#  'scan_visnir_1414_pcnt': 41.8,
#  'scan_visnir_1416_pcnt': 42.2,
#  'scan_visnir_1418_pcnt': 42.8,
#  'scan_visnir_1420_pcnt': 43.6,
#  'scan_visnir_1422_pcnt': 44.3,
#  'scan_visnir_1424_pcnt': 44.9,
#  'scan_visnir_1426_pcnt': 45.5,
#  'scan_visnir_1428_pcnt': 46.0,
#  'scan_visnir_1430_pcnt': 46.4,
#  'scan_visnir_1432_pcnt': 46.8,
#  'scan_visnir_1434_pcnt': 47.2,
#  'scan_visnir_1436_pcnt': 47.5,
#  'scan_visnir_1438_pcnt': 47.8,
#  'scan_visnir_1440_pcnt': 48.1,
#  'scan_visnir_1442_pcnt': 48.3,
#  'scan_visnir_1444_pcnt': 48.6,
#  'scan_visnir_1446_pcnt': 48.7,
#  'scan_visnir_1448_pcnt': 48.9,
#  'scan_visnir_1450_pcnt': 49.0,
#  'scan_visnir_1452_pcnt': 49.2,
#  'scan_visnir_1454_pcnt': 49.3,
#  'scan_visnir_1456_pcnt': 49.3,
#  'scan_visnir_1458_pcnt': 49.4,
#  'scan_visnir_1460_pcnt': 49.5,
#  'scan_visnir_1462_pcnt': 49.6,
#  'scan_visnir_1464_pcnt': 49.7,
#  'scan_visnir_1466_pcnt': 49.8,
#  'scan_visnir_1468_pcnt': 49.9,
#  'scan_visnir_1470_pcnt': 50.0,
#  'scan_visnir_1472_pcnt': 50.1,
#  'scan_visnir_1474_pcnt': 50.3,
#  'scan_visnir_1476_pcnt': 50.4,
#  'scan_visnir_1478_pcnt': 50.6,
#  'scan_visnir_1480_pcnt': 50.7,
#  'scan_visnir_1482_pcnt': 50.9,
#  'scan_visnir_1484_pcnt': 51.0,
#  'scan_visnir_1486_pcnt': 51.1,
#  'scan_visnir_1488_pcnt': 51.3,
#  'scan_visnir_1490_pcnt': 51.4,
#  'scan_visnir_1492_pcnt': 51.5,
#  'scan_visnir_1494_pcnt': 51.6,
#  'scan_visnir_1496_pcnt': 51.7,
#  'scan_visnir_1498_pcnt': 51.8,
#  'scan_visnir_1500_pcnt': 51.9,
#  'scan_visnir_1502_pcnt': 52.0,
#  'scan_visnir_1504_pcnt': 52.1,
#  'scan_visnir_1506_pcnt': 52.2,
#  'scan_visnir_1508_pcnt': 52.3,
#  'scan_visnir_1510_pcnt': 52.4,
#  'scan_visnir_1512_pcnt': 52.5,
#  'scan_visnir_1514_pcnt': 52.5,
#  'scan_visnir_1516_pcnt': 52.6,
#  'scan_visnir_1518_pcnt': 52.7,
#  'scan_visnir_1520_pcnt': 52.8,
#  'scan_visnir_1522_pcnt': 52.8,
#  'scan_visnir_1524_pcnt': 52.9,
#  'scan_visnir_1526_pcnt': 53.0,
#  'scan_visnir_1528_pcnt': 53.0,
#  'scan_visnir_1530_pcnt': 53.1,
#  'scan_visnir_1532_pcnt': 53.2,
#  'scan_visnir_1534_pcnt': 53.2,
#  'scan_visnir_1536_pcnt': 53.3,
#  'scan_visnir_1538_pcnt': 53.3,
#  'scan_visnir_1540_pcnt': 53.4,
#  'scan_visnir_1542_pcnt': 53.4,
#  'scan_visnir_1544_pcnt': 53.5,
#  'scan_visnir_1546_pcnt': 53.5,
#  'scan_visnir_1548_pcnt': 53.6,
#  'scan_visnir_1550_pcnt': 53.6,
#  'scan_visnir_1552_pcnt': 53.7,
#  'scan_visnir_1554_pcnt': 53.7,
#  'scan_visnir_1556_pcnt': 53.7,
#  'scan_visnir_1558_pcnt': 53.8,
#  'scan_visnir_1560_pcnt': 53.8,
#  'scan_visnir_1562_pcnt': 53.9,
#  'scan_visnir_1564_pcnt': 53.9,
#  'scan_visnir_1566_pcnt': 53.9,
#  'scan_visnir_1568_pcnt': 54.0,
#  'scan_visnir_1570_pcnt': 54.0,
#  'scan_visnir_1572_pcnt': 54.0,
#  'scan_visnir_1574_pcnt': 54.1,
#  'scan_visnir_1576_pcnt': 54.1,
#  'scan_visnir_1578_pcnt': 54.1,
#  'scan_visnir_1580_pcnt': 54.2,
#  'scan_visnir_1582_pcnt': 54.2,
#  'scan_visnir_1584_pcnt': 54.2,
#  'scan_visnir_1586_pcnt': 54.2,
#  'scan_visnir_1588_pcnt': 54.3,
#  'scan_visnir_1590_pcnt': 54.3,
#  'scan_visnir_1592_pcnt': 54.3,
#  'scan_visnir_1594_pcnt': 54.3,
#  'scan_visnir_1596_pcnt': 54.3,
#  'scan_visnir_1598_pcnt': 54.4,
#  'scan_visnir_1600_pcnt': 54.4,
#  'scan_visnir_1602_pcnt': 54.4,
#  'scan_visnir_1604_pcnt': 54.4,
#  'scan_visnir_1606_pcnt': 54.4,
#  'scan_visnir_1608_pcnt': 54.5,
#  'scan_visnir_1610_pcnt': 54.5,
#  'scan_visnir_1612_pcnt': 54.5,
#  'scan_visnir_1614_pcnt': 54.5,
#  'scan_visnir_1616_pcnt': 54.5,
#  'scan_visnir_1618_pcnt': 54.5,
#  'scan_visnir_1620_pcnt': 54.5,
#  'scan_visnir_1622_pcnt': 54.6,
#  'scan_visnir_1624_pcnt': 54.6,
#  'scan_visnir_1626_pcnt': 54.6,
#  'scan_visnir_1628_pcnt': 54.6,
#  'scan_visnir_1630_pcnt': 54.6,
#  'scan_visnir_1632_pcnt': 54.6,
#  'scan_visnir_1634_pcnt': 54.6,
#  'scan_visnir_1636_pcnt': 54.6,
#  'scan_visnir_1638_pcnt': 54.6,
#  'scan_visnir_1640_pcnt': 54.6,
#  'scan_visnir_1642_pcnt': 54.6,
#  'scan_visnir_1644_pcnt': 54.6,
#  'scan_visnir_1646_pcnt': 54.6,
#  'scan_visnir_1648_pcnt': 54.6,
#  'scan_visnir_1650_pcnt': 54.6,
#  'scan_visnir_1652_pcnt': 54.7,
#  'scan_visnir_1654_pcnt': 54.7,
#  'scan_visnir_1656_pcnt': 54.7,
#  'scan_visnir_1658_pcnt': 54.7,
#  'scan_visnir_1660_pcnt': 54.7,
#  'scan_visnir_1662_pcnt': 54.7,
#  'scan_visnir_1664_pcnt': 54.7,
#  'scan_visnir_1666_pcnt': 54.7,
#  'scan_visnir_1668_pcnt': 54.7,
#  'scan_visnir_1670_pcnt': 54.7,
#  'scan_visnir_1672_pcnt': 54.7,
#  'scan_visnir_1674_pcnt': 54.7,
#  'scan_visnir_1676_pcnt': 54.7,
#  'scan_visnir_1678_pcnt': 54.7,
#  'scan_visnir_1680_pcnt': 54.7,
#  'scan_visnir_1682_pcnt': 54.7,
#  'scan_visnir_1684_pcnt': 54.7,
#  'scan_visnir_1686_pcnt': 54.6,
#  'scan_visnir_1688_pcnt': 54.6,
#  'scan_visnir_1690_pcnt': 54.6,
#  'scan_visnir_1692_pcnt': 54.6,
#  'scan_visnir_1694_pcnt': 54.6,
#  'scan_visnir_1696_pcnt': 54.6,
#  'scan_visnir_1698_pcnt': 54.6,
#  'scan_visnir_1700_pcnt': 54.6,
#  'scan_visnir_1702_pcnt': 54.6,
#  'scan_visnir_1704_pcnt': 54.5,
#  'scan_visnir_1706_pcnt': 54.5,
#  'scan_visnir_1708_pcnt': 54.5,
#  'scan_visnir_1710_pcnt': 54.5,
#  'scan_visnir_1712_pcnt': 54.5,
#  'scan_visnir_1714_pcnt': 54.5,
#  'scan_visnir_1716_pcnt': 54.4,
#  'scan_visnir_1718_pcnt': 54.4,
#  'scan_visnir_1720_pcnt': 54.4,
#  'scan_visnir_1722_pcnt': 54.4,
#  'scan_visnir_1724_pcnt': 54.3,
#  'scan_visnir_1726_pcnt': 54.3,
#  'scan_visnir_1728_pcnt': 54.3,
#  'scan_visnir_1730_pcnt': 54.2,
#  'scan_visnir_1732_pcnt': 54.2,
#  'scan_visnir_1734_pcnt': 54.2,
#  'scan_visnir_1736_pcnt': 54.1,
#  'scan_visnir_1738_pcnt': 54.1,
#  'scan_visnir_1740_pcnt': 54.0,
#  'scan_visnir_1742_pcnt': 54.0,
#  'scan_visnir_1744_pcnt': 53.9,
#  'scan_visnir_1746_pcnt': 53.9,
#  'scan_visnir_1748_pcnt': 53.9,
#  'scan_visnir_1750_pcnt': 53.8,
#  'scan_visnir_1752_pcnt': 53.8,
#  'scan_visnir_1754_pcnt': 53.7,
#  'scan_visnir_1756_pcnt': 53.7,
#  'scan_visnir_1758_pcnt': 53.6,
#  'scan_visnir_1760_pcnt': 53.6,
#  'scan_visnir_1762_pcnt': 53.6,
#  'scan_visnir_1764_pcnt': 53.5,
#  'scan_visnir_1766_pcnt': 53.5,
#  'scan_visnir_1768_pcnt': 53.4,
#  'scan_visnir_1770_pcnt': 53.4,
#  'scan_visnir_1772_pcnt': 53.3,
#  'scan_visnir_1774_pcnt': 53.3,
#  'scan_visnir_1776_pcnt': 53.2,
#  'scan_visnir_1778_pcnt': 53.2,
#  'scan_visnir_1780_pcnt': 53.1,
#  'scan_visnir_1782_pcnt': 53.1,
#  'scan_visnir_1784_pcnt': 53.0,
#  'scan_visnir_1786_pcnt': 53.0,
#  'scan_visnir_1788_pcnt': 53.0,
#  'scan_visnir_1790_pcnt': 52.9,
#  'scan_visnir_1792_pcnt': 52.9,
#  'scan_visnir_1794_pcnt': 52.9,
#  'scan_visnir_1796_pcnt': 52.9,
#  'scan_visnir_1798_pcnt': 52.8,
#  'scan_visnir_1800_pcnt': 52.8,
#  'scan_visnir_1802_pcnt': 52.8,
#  'scan_visnir_1804_pcnt': 52.8,
#  'scan_visnir_1806_pcnt': 52.8,
#  'scan_visnir_1808_pcnt': 52.8,
#  'scan_visnir_1810_pcnt': 52.8,
#  'scan_visnir_1812_pcnt': 52.8,
#  'scan_visnir_1814_pcnt': 52.8,
#  'scan_visnir_1816_pcnt': 52.8,
#  'scan_visnir_1818_pcnt': 52.8,
#  'scan_visnir_1820_pcnt': 52.8,
#  'scan_visnir_1822_pcnt': 52.7,
#  'scan_visnir_1824_pcnt': 52.7,
#  'scan_visnir_1826_pcnt': 52.7,
#  'scan_visnir_1828_pcnt': 52.7,
#  'scan_visnir_1830_pcnt': 52.7,
#  'scan_visnir_1832_pcnt': 52.6,
#  'scan_visnir_1834_pcnt': 52.6,
#  'scan_visnir_1836_pcnt': 52.6,
#  'scan_visnir_1838_pcnt': 52.5,
#  'scan_visnir_1840_pcnt': 52.5,
#  'scan_visnir_1842_pcnt': 52.5,
#  'scan_visnir_1844_pcnt': 52.4,
#  'scan_visnir_1846_pcnt': 52.4,
#  'scan_visnir_1848_pcnt': 52.3,
#  'scan_visnir_1850_pcnt': 52.2,
#  'scan_visnir_1852_pcnt': 52.1,
#  'scan_visnir_1854_pcnt': 52.0,
#  'scan_visnir_1856_pcnt': 51.9,
#  'scan_visnir_1858_pcnt': 51.7,
#  'scan_visnir_1860_pcnt': 51.5,
#  'scan_visnir_1862_pcnt': 51.3,
#  'scan_visnir_1864_pcnt': 51.0,
#  'scan_visnir_1866_pcnt': 50.6,
#  'scan_visnir_1868_pcnt': 50.2,
#  'scan_visnir_1870_pcnt': 49.7,
#  'scan_visnir_1872_pcnt': 49.1,
#  'scan_visnir_1874_pcnt': 48.4,
#  'scan_visnir_1876_pcnt': 47.7,
#  'scan_visnir_1878_pcnt': 46.9,
#  'scan_visnir_1880_pcnt': 46.0,
#  'scan_visnir_1882_pcnt': 45.2,
#  'scan_visnir_1884_pcnt': 44.3,
#  'scan_visnir_1886_pcnt': 43.3,
#  'scan_visnir_1888_pcnt': 42.3,
#  'scan_visnir_1890_pcnt': 41.2,
#  'scan_visnir_1892_pcnt': 40.1,
#  'scan_visnir_1894_pcnt': 39.0,
#  'scan_visnir_1896_pcnt': 37.8,
#  'scan_visnir_1898_pcnt': 36.7,
#  'scan_visnir_1900_pcnt': 35.7,
#  'scan_visnir_1902_pcnt': 34.8,
#  'scan_visnir_1904_pcnt': 34.1,
#  'scan_visnir_1906_pcnt': 33.6,
#  'scan_visnir_1908_pcnt': 33.2,
#  'scan_visnir_1910_pcnt': 33.0,
#  'scan_visnir_1912_pcnt': 33.0,
#  'scan_visnir_1914_pcnt': 33.1,
#  'scan_visnir_1916_pcnt': 33.4,
#  'scan_visnir_1918_pcnt': 33.7,
#  'scan_visnir_1920_pcnt': 34.0,
#  'scan_visnir_1922_pcnt': 34.4,
#  'scan_visnir_1924_pcnt': 34.8,
#  'scan_visnir_1926_pcnt': 35.1,
#  'scan_visnir_1928_pcnt': 35.5,
#  'scan_visnir_1930_pcnt': 35.9,
#  'scan_visnir_1932_pcnt': 36.2,
#  'scan_visnir_1934_pcnt': 36.5,
#  'scan_visnir_1936_pcnt': 36.8,
#  'scan_visnir_1938_pcnt': 37.0,
#  'scan_visnir_1940_pcnt': 37.3,
#  'scan_visnir_1942_pcnt': 37.5,
#  'scan_visnir_1944_pcnt': 37.7,
#  'scan_visnir_1946_pcnt': 38.0,
#  'scan_visnir_1948_pcnt': 38.2,
#  'scan_visnir_1950_pcnt': 38.4,
#  'scan_visnir_1952_pcnt': 38.5,
#  'scan_visnir_1954_pcnt': 38.7,
#  'scan_visnir_1956_pcnt': 38.9,
#  'scan_visnir_1958_pcnt': 39.1,
#  'scan_visnir_1960_pcnt': 39.3,
#  'scan_visnir_1962_pcnt': 39.5,
#  'scan_visnir_1964_pcnt': 39.6,
#  'scan_visnir_1966_pcnt': 39.8,
#  'scan_visnir_1968_pcnt': 40.0,
#  'scan_visnir_1970_pcnt': 40.2,
#  'scan_visnir_1972_pcnt': 40.4,
#  'scan_visnir_1974_pcnt': 40.5,
#  'scan_visnir_1976_pcnt': 40.7,
#  'scan_visnir_1978_pcnt': 40.9,
#  'scan_visnir_1980_pcnt': 41.1,
#  'scan_visnir_1982_pcnt': 41.3,
#  'scan_visnir_1984_pcnt': 41.5,
#  'scan_visnir_1986_pcnt': 41.8,
#  'scan_visnir_1988_pcnt': 42.0,
#  'scan_visnir_1990_pcnt': 42.2,
#  'scan_visnir_1992_pcnt': 42.4,
#  'scan_visnir_1994_pcnt': 42.6,
#  'scan_visnir_1996_pcnt': 42.8,
#  'scan_visnir_1998_pcnt': 43.0,
#  'scan_visnir_2000_pcnt': 43.2,
#  'scan_visnir_2002_pcnt': 43.4,
#  'scan_visnir_2004_pcnt': 43.6,
#  'scan_visnir_2006_pcnt': 43.8,
#  'scan_visnir_2008_pcnt': 44.0,
#  'scan_visnir_2010_pcnt': 44.2,
#  'scan_visnir_2012_pcnt': 44.4,
#  'scan_visnir_2014_pcnt': 44.6,
#  'scan_visnir_2016_pcnt': 44.8,
#  'scan_visnir_2018_pcnt': 44.9,
#  'scan_visnir_2020_pcnt': 45.1,
#  'scan_visnir_2022_pcnt': 45.3,
#  'scan_visnir_2024_pcnt': 45.4,
#  'scan_visnir_2026_pcnt': 45.6,
#  'scan_visnir_2028_pcnt': 45.7,
#  'scan_visnir_2030_pcnt': 45.9,
#  'scan_visnir_2032_pcnt': 46.0,
#  'scan_visnir_2034_pcnt': 46.2,
#  'scan_visnir_2036_pcnt': 46.3,
#  'scan_visnir_2038_pcnt': 46.4,
#  'scan_visnir_2040_pcnt': 46.5,
#  'scan_visnir_2042_pcnt': 46.6,
#  'scan_visnir_2044_pcnt': 46.7,
#  'scan_visnir_2046_pcnt': 46.8,
#  'scan_visnir_2048_pcnt': 46.9,
#  'scan_visnir_2050_pcnt': 47.0,
#  'scan_visnir_2052_pcnt': 47.0,
#  'scan_visnir_2054_pcnt': 47.1,
#  'scan_visnir_2056_pcnt': 47.1,
#  'scan_visnir_2058_pcnt': 47.2,
#  'scan_visnir_2060_pcnt': 47.3,
#  'scan_visnir_2062_pcnt': 47.3,
#  'scan_visnir_2064_pcnt': 47.4,
#  'scan_visnir_2066_pcnt': 47.4,
#  'scan_visnir_2068_pcnt': 47.4,
#  'scan_visnir_2070_pcnt': 47.4,
#  'scan_visnir_2072_pcnt': 47.5,
#  'scan_visnir_2074_pcnt': 47.5,
#  'scan_visnir_2076_pcnt': 47.5,
#  'scan_visnir_2078_pcnt': 47.5,
#  'scan_visnir_2080_pcnt': 47.5,
#  'scan_visnir_2082_pcnt': 47.5,
#  'scan_visnir_2084_pcnt': 47.5,
#  'scan_visnir_2086_pcnt': 47.5,
#  'scan_visnir_2088_pcnt': 47.5,
#  'scan_visnir_2090_pcnt': 47.5,
#  'scan_visnir_2092_pcnt': 47.5,
#  'scan_visnir_2094_pcnt': 47.5,
#  'scan_visnir_2096_pcnt': 47.6,
#  'scan_visnir_2098_pcnt': 47.6,
#  'scan_visnir_2100_pcnt': 47.6,
#  'scan_visnir_2102_pcnt': 47.5,
#  'scan_visnir_2104_pcnt': 47.5,
#  'scan_visnir_2106_pcnt': 47.5,
#  'scan_visnir_2108_pcnt': 47.5,
#  'scan_visnir_2110_pcnt': 47.5,
#  'scan_visnir_2112_pcnt': 47.5,
#  'scan_visnir_2114_pcnt': 47.5,
#  'scan_visnir_2116_pcnt': 47.6,
#  'scan_visnir_2118_pcnt': 47.6,
#  'scan_visnir_2120_pcnt': 47.6,
#  'scan_visnir_2122_pcnt': 47.6,
#  'scan_visnir_2124_pcnt': 47.6,
#  'scan_visnir_2126_pcnt': 47.5,
#  'scan_visnir_2128_pcnt': 47.5,
#  'scan_visnir_2130_pcnt': 47.4,
#  'scan_visnir_2132_pcnt': 47.2,
#  'scan_visnir_2134_pcnt': 47.1,
#  'scan_visnir_2136_pcnt': 46.9,
#  'scan_visnir_2138_pcnt': 46.6,
#  'scan_visnir_2140_pcnt': 46.3,
#  'scan_visnir_2142_pcnt': 46.0,
#  'scan_visnir_2144_pcnt': 45.7,
#  'scan_visnir_2146_pcnt': 45.3,
#  'scan_visnir_2148_pcnt': 44.9,
#  'scan_visnir_2150_pcnt': 44.4,
#  'scan_visnir_2152_pcnt': 43.9,
#  'scan_visnir_2154_pcnt': 43.4,
#  'scan_visnir_2156_pcnt': 43.0,
#  'scan_visnir_2158_pcnt': 42.5,
#  'scan_visnir_2160_pcnt': 42.0,
#  'scan_visnir_2162_pcnt': 41.6,
#  'scan_visnir_2164_pcnt': 41.2,
#  'scan_visnir_2166_pcnt': 40.7,
#  'scan_visnir_2168_pcnt': 40.3,
#  'scan_visnir_2170_pcnt': 39.9,
#  'scan_visnir_2172_pcnt': 39.6,
#  'scan_visnir_2174_pcnt': 39.2,
#  'scan_visnir_2176_pcnt': 38.8,
#  'scan_visnir_2178_pcnt': 38.5,
#  'scan_visnir_2180_pcnt': 38.1,
#  'scan_visnir_2182_pcnt': 37.8,
#  'scan_visnir_2184_pcnt': 37.5,
#  'scan_visnir_2186_pcnt': 37.2,
#  'scan_visnir_2188_pcnt': 36.9,
#  'scan_visnir_2190_pcnt': 36.6,
#  'scan_visnir_2192_pcnt': 36.3,
#  'scan_visnir_2194_pcnt': 35.9,
#  'scan_visnir_2196_pcnt': 35.5,
#  'scan_visnir_2198_pcnt': 35.1,
#  'scan_visnir_2200_pcnt': 34.7,
#  'scan_visnir_2202_pcnt': 34.4,
#  'scan_visnir_2204_pcnt': 34.2,
#  'scan_visnir_2206_pcnt': 34.2,
#  'scan_visnir_2208_pcnt': 34.4,
#  'scan_visnir_2210_pcnt': 34.9,
#  'scan_visnir_2212_pcnt': 35.5,
#  'scan_visnir_2214_pcnt': 36.2,
#  'scan_visnir_2216_pcnt': 36.8,
#  'scan_visnir_2218_pcnt': 37.5,
#  'scan_visnir_2220_pcnt': 38.0,
#  'scan_visnir_2222_pcnt': 38.5,
#  'scan_visnir_2224_pcnt': 38.9,
#  'scan_visnir_2226_pcnt': 39.2,
#  'scan_visnir_2228_pcnt': 39.5,
#  'scan_visnir_2230_pcnt': 39.7,
#  'scan_visnir_2232_pcnt': 39.9,
#  'scan_visnir_2234_pcnt': 40.0,
#  'scan_visnir_2236_pcnt': 40.1,
#  'scan_visnir_2238_pcnt': 40.3,
#  'scan_visnir_2240_pcnt': 40.4,
#  'scan_visnir_2242_pcnt': 40.5,
#  'scan_visnir_2244_pcnt': 40.6,
#  'scan_visnir_2246_pcnt': 40.7,
#  'scan_visnir_2248_pcnt': 40.8,
#  'scan_visnir_2250_pcnt': 40.9,
#  'scan_visnir_2252_pcnt': 40.9,
#  'scan_visnir_2254_pcnt': 41.0,
#  'scan_visnir_2256_pcnt': 41.1,
#  'scan_visnir_2258_pcnt': 41.1,
#  'scan_visnir_2260_pcnt': 41.2,
#  'scan_visnir_2262_pcnt': 41.2,
#  'scan_visnir_2264_pcnt': 41.2,
#  'scan_visnir_2266_pcnt': 41.2,
#  'scan_visnir_2268_pcnt': 41.2,
#  'scan_visnir_2270_pcnt': 41.2,
#  'scan_visnir_2272_pcnt': 41.1,
#  'scan_visnir_2274_pcnt': 41.1,
#  'scan_visnir_2276_pcnt': 41.0,
#  'scan_visnir_2278_pcnt': 40.9,
#  'scan_visnir_2280_pcnt': 40.8,
#  'scan_visnir_2282_pcnt': 40.7,
#  'scan_visnir_2284_pcnt': 40.6,
#  'scan_visnir_2286_pcnt': 40.4,
#  'scan_visnir_2288_pcnt': 40.3,
#  'scan_visnir_2290_pcnt': 40.1,
#  'scan_visnir_2292_pcnt': 40.0,
#  'scan_visnir_2294_pcnt': 39.8,
#  'scan_visnir_2296_pcnt': 39.6,
#  'scan_visnir_2298_pcnt': 39.5,
#  'scan_visnir_2300_pcnt': 39.3,
#  'scan_visnir_2302_pcnt': 39.1,
#  'scan_visnir_2304_pcnt': 39.0,
#  'scan_visnir_2306_pcnt': 38.8,
#  'scan_visnir_2308_pcnt': 38.6,
#  'scan_visnir_2310_pcnt': 38.4,
#  'scan_visnir_2312_pcnt': 38.3,
#  ...}

# %%
get_collection_fields(db,'soillab')
# Out:
# dict_keys(['_id', 'id_layer_uuid_c', 'id_layer_local_c', 'sample_contact_name_utf8_txt', 'sample_contact_email_ietf_email', 'acid_tea_usda4b2_cmolkg', 'al_ox_usda_4g2_wpct', 'c_tot_usda_4h2_wpct', 'clay_tot_usda_3a1_wpct', 'oc_usda_calc_wpct', 'fe_ox_usda_4g2_wpct', 'n_tot_usda_4h2_wpct', 'ph_h2o_usda_4c1_index', 'ph_cacl2_usda_4c1_index', 'ph_naf_usda_4c1_index', 'sand_tot_usda_3a1_wpct', 'silt_tot_usda_3a1_wpct', 'clay_tot_usda_3a1_wpct_1', 's_tot_usda_4h2_wpct', 'wr_1500kbar_usda_3c2_wpct'])

# %%
get_sample_record(db,'soillab')
# Out:
# {'_id': ObjectId('645bb550f1aab744907fc48a'),
#  'id_layer_uuid_c': '480f41ca00f52e4d830b60438ce41685',
#  'id_layer_local_c': 197861,
#  'sample_contact_name_utf8_txt': 'Scarlett Murphy',
#  'sample_contact_email_ietf_email': 'Scarlett.Murphy@usda.gov',
#  'bsat_usda_4b4_wpct': 94.0,
#  'bd_clod_usda_3b1_gcm3': 1.28869193,
#  'bd_od_usda_3b2_gcm3': 1.57643479,
#  'ca_ext_usda_4b1_cmolkg': 11.1547593,
#  'c_tot_usda_4h2_wpct': 0.33808661,
#  'cec_ext_usda_4b1_cmolkg': 14.3999532,
#  'clay_tot_usda_3a1_wpct': 18.3806339,
#  'ec_w_usda_4f1_dsm': 0.09505703,
#  'oc_usda_calc_wpct': 0.34,
#  'mg_ext_usda_4b1_cmolkg': 1.8773946,
#  'n_tot_usda_4h2_wpct': 0.10245049,
#  'ph_h2o_usda_4c1_index': 6.12,
#  'ph_cacl2_usda_4c1_index': 5.4,
#  'p_ext_usda_4d6_mgkg': 16.3074199,
#  'k_ext_usda_4b1_cmolkg': 0.3500309,
#  'sand_tot_usda_3a1_wpct': 16.0,
#  'silt_tot_usda_3a1_wpct': 65.6,
#  'clay_tot_usda_3a1_wpct_1': 18.3806339,
#  'na_ext_usda_4b1_cmolkg': 0.0396874,
#  's_tot_usda_4h2_wpct': 0.01639208,
#  'sum_bases_4b4b2a_cmolkg': 13.5,
#  'wr_33kbar_usda_3c1_wpct': 23.1229354,
#  'wr_1500kbar_usda_3c2_wpct': 11.9513678}

# %%
#id_layer_uuid_c connects the data in the collections
display(get_data_collection(db,'mir',query={'id_layer_uuid_c': 'a0f56bb43799522951d7a3d3a5b4e597'}))
display(get_data_collection(db,'soillab',query={'id_layer_uuid_c': 'a0f56bb43799522951d7a3d3a5b4e597'}))
display(get_data_collection(db,'soilsite',query={'id_layer_uuid_c': 'a0f56bb43799522951d7a3d3a5b4e597'}))
# Out:
#                         _id                    id_scan_uuid_c id_scan_local_c  \
# 0  645bb31ef1aab744907df3e8  2469a7006a4ee9b5559f754578f21049          139832
#
#                     id_layer_uuid_c  id_layer_local_c  \
# 0  a0f56bb43799522951d7a3d3a5b4e597             56286
#
#                       model_name_utf8_txt         model_code_any_c  \
# 0  Bruker Vertex 70 with HTS-XT accessory  Bruker_Vertex_70.HTS.XT
#
#   method_light_source_any_c method_preparation_any_c  \
# 0                       KBr
#
#                                      scan_file_any_c  ... scan_mir_3984_abs  \
# 0  139832XS01.0; 139832XS02.0; 139832XS03.0; 1398...  ...             148.0
#
#   scan_mir_3986_abs scan_mir_3988_abs scan_mir_3990_abs scan_mir_3992_abs  \
# 0             148.0             147.0             147.0             146.0
#
#   scan_mir_3994_abs scan_mir_3996_abs  scan_mir_3998_abs  scan_mir_4000_abs  \
# 0             146.0             146.0              145.0              145.0
#
#                                _row
# 0  2469a7006a4ee9b5559f754578f21049
#
# [1 rows x 1722 columns]
#                         _id                   id_layer_uuid_c  \
# 0  645bb546f1aab744907f1a78  a0f56bb43799522951d7a3d3a5b4e597
#
#    id_layer_local_c sample_contact_name_utf8_txt  \
# 0             56286              Scarlett Murphy
#
#   sample_contact_email_ietf_email  al_dith_usda_4g1_wpct  bsat_usda_4b4_wpct  \
# 0        Scarlett.Murphy@usda.gov               0.030222               100.0
#
#    bd_clod_usda_3b1_gcm3  bd_od_usda_3b2_gcm3  ca_ext_usda_4b1_cmolkg  ...  \
# 0               1.992791             2.024482               39.115208  ...
#
#    p_ext_usda_4d6_mgkg  k_ext_usda_4b1_cmolkg  sand_tot_usda_3a1_wpct  \
# 0             0.200853               0.133651                    43.5
#
#    silt_tot_usda_3a1_wpct  clay_tot_usda_3a1_wpct_1  na_ext_usda_4b1_cmolkg  \
# 0                    41.8                 14.654497                     0.0
#
#    s_tot_usda_4h2_wpct  sum_bases_4b4b2a_cmolkg  wr_33kbar_usda_3c1_wpct  \
# 0                  0.0                     41.7                10.998674
#
#    wr_1500kbar_usda_3c2_wpct
# 0                   6.603774
#
# [1 rows x 30 columns]
#                         _id id_location_olc_c  \
# 0  645bb558f1aab74490801cdd       86HQF26F+M9
#
#                     id_layer_uuid_c observation_ogc_schema_title_ogc_txt  \
# 0  a0f56bb43799522951d7a3d3a5b4e597       Open Soil Spectroscopy Library
#
#        observation_ogc_schema_idn_url  \
# 0  https://soilspectroscopy.github.io
#
#   observation_date_begin_iso_8601_yyyy_mm_dd  \
# 0                                 2010-11-25
#
#   observation_date_end_iso_8601_yyyy_mm_dd location_address_utf8_txt  \
# 0                               2010-11-25               De Kalb Co.
#
#   location_country_iso_3166_c location_method_any_c  ... id_user_site_ascii_c  \
# 0                         USA                   GPS  ...          S10IN033002
#
#                                pedon_taxa_usda_c layer_sequence_usda_uint16  \
# 0  Fine-loamy, illitic, mesic Oxyaquic Argiudoll                         11
#
#    layer_type_usda_c  layer_field_label_any_c  layer_upper_depth_usda_cm  \
# 0                                                                   94.0
#
#   layer_lower_depth_usda_cm horizon_designation_usda_c  \
# 0                     115.0                       B__2
#
#   horizon_designation_discontinuity_usda_c layer_texture_usda_c
# 0                                        2
#
# [1 rows x 35 columns]

# %% [markdown]
# # Q1: What Predicts Carbon? (Work in progress)
#
# Columns:
#
# - oc_iso.10694_w.pct	Organic Carbon,	weight percent, Estimated Organic Carbon based on Total C
# - oc_usda.c1059_w.pct	Organic Carbon, Total C without CaCO3, 	weight percent,	Estimated Organic Carbon based on Total C
# - oc_usda.c729_w.pct	Organic Carbon, Total C without CaCO3, S prep	weight percent

# %%
mir.describe()

# %%
visnir.describe()

# %%
test[:10].to_csv(f'{data_dir}/small.csv')

# %%
test.describe()
# Out:
#        longitude.point_wgs84_dd  latitude.point_wgs84_dd  \
# count              87707.000000             87707.000000
# mean                 -38.610303                41.898495
# std                   60.729395                15.616700
# min                 -173.198001               -46.420000
# 25%                  -97.112503                38.838974
# 50%                   -5.155099                43.535632
# 75%                   14.421631                48.915910
# max                  177.910000                71.316556
#
#        layer.sequence_usda_uint16  layer.upper.depth_usda_cm  \
# count                 7455.000000              134827.000000
# mean                     2.771831                  23.797749
# std                      2.305919                  42.129258
# min                      0.000000                   0.000000
# 25%                      1.000000                   0.000000
# 50%                      2.000000                   2.000000
# 75%                      4.000000                  33.000000
# max                     56.000000                1676.000000
#
#        layer.lower.depth_usda_cm  longitude.county_wgs84_dd  \
# count              132148.000000               83222.000000
# mean                   45.729387                 -98.936793
# std                    50.385662                  17.716686
# min                     0.000000                -167.994145
# 25%                    20.000000                -111.549030
# 50%                    20.000000                 -96.688800
# 75%                    61.000000                 -86.260570
# max                  1692.000000                   0.315575
#
#        latitude.county_wgs84_dd  location.point.error_any_m  \
# count              83222.000000                87707.000000
# mean                  40.705190                  484.097723
# std                    6.497736                  484.162796
# min                   17.980180                   30.000000
# 25%                   37.191760                   30.000000
# 50%                   40.733550                   30.000000
# 75%                   44.545095                 1000.000000
# max                   69.694275                 1111.000000
#
#        acidity_usda.a795_cmolc.kg  aggstb_usda.a1_w.pct  ...  \
# count                30061.000000           3218.000000  ...
# mean                    14.649964             37.037290  ...
# std                     24.740795             30.384008  ...
# min                      0.000000              0.000000  ...
# 25%                      3.499710              9.000000  ...
# 50%                      7.072200             28.000000  ...
# 75%                     13.802810             63.000000  ...
# max                    282.720020            106.000000  ...
#
#        scan_visnir.2482_ref  scan_visnir.2484_ref  scan_visnir.2486_ref  \
# count          64644.000000          64644.000000          64644.000000
# mean               0.368747              0.368093              0.367478
# std                0.087191              0.087128              0.087068
# min                0.071247              0.071217              0.070881
# 25%                0.310723              0.310050              0.309408
# 50%                0.366867              0.366178              0.365537
# 75%                0.423077              0.422329              0.421630
# max                0.877398              0.875266              0.872904
#
#        scan_visnir.2488_ref  scan_visnir.2490_ref  scan_visnir.2492_ref  \
# count          64644.000000          64644.000000          64644.000000
# mean               0.366915              0.366415              0.365985
# std                0.087019              0.086977              0.086943
# min                0.071156              0.070903              0.070679
# 25%                0.308865              0.308392              0.307928
# 50%                0.364953              0.364406              0.363936
# 75%                0.420994              0.420454              0.419968
# max                0.870909              0.869880              0.870378
#
#        scan_visnir.2494_ref  scan_visnir.2496_ref  scan_visnir.2498_ref  \
# count          64644.000000          64644.000000          64644.000000
# mean               0.365614              0.365312              0.365081
# std                0.086917              0.086894              0.086883
# min                0.070936              0.071058              0.071069
# 25%                0.307547              0.307253              0.307030
# 50%                0.363559              0.363240              0.362983
# 75%                0.419590              0.419228              0.419006
# max                0.872813              0.877563              0.885003
#
#        scan_visnir.2500_ref
# count          64644.000000
# mean               0.364867
# std                0.086888
# min                0.070392
# 25%                0.306842
# 50%                0.362768
# 75%                0.418781
# max                0.895508
#
# [8 rows x 2861 columns]

# %%
test.columns
# Out:
# Index(['dataset.code_ascii_txt', 'id.layer_local_c', 'id.layer_uuid_txt',
#        'id.project_ascii_txt', 'id.location_olc_txt',
#        'id.dataset.site_ascii_txt', 'id.scan_local_c',
#        'longitude.point_wgs84_dd', 'latitude.point_wgs84_dd',
#        'layer.sequence_usda_uint16',
#        ...
#        'scan_visnir.2482_ref', 'scan_visnir.2484_ref', 'scan_visnir.2486_ref',
#        'scan_visnir.2488_ref', 'scan_visnir.2490_ref', 'scan_visnir.2492_ref',
#        'scan_visnir.2494_ref', 'scan_visnir.2496_ref', 'scan_visnir.2498_ref',
#        'scan_visnir.2500_ref'],
#       dtype='object', length=2910)
